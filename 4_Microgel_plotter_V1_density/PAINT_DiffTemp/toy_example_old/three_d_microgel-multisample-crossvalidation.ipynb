# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import trimesh
import argparse
import os
import time
import numpy as np
import torch
import torch.optim as optim
import lib.utils as utils
from lib.utils import standard_normal_logprob
from lib.utils import count_nfe, count_total_time
from lib.utils import build_model_tabular
import pandas as pd
import random
from lib.visualize_flow import visualize_transform
import lib.layers.odefunc as odefunc
from matplotlib import pyplot as plt
# %matplotlib inline 
import glob

# %%
SOLVERS = ["dopri5"]
parser = argparse.ArgumentParser('SoftFlow')
parser.add_argument(
    '--data', choices=['2spirals_1d','2spirals_2d', 'swissroll_1d','swissroll_2d', 'circles_1d', 'circles_2d', '2sines_1d', 'target_1d'],
    type=str, default='3d_microgel'
)
parser.add_argument("--layer_type", type=str, default="concatsquash", choices=["concatsquash"])
parser.add_argument('--dims', type=str, default='64-64-64')
parser.add_argument("--num_blocks", type=int, default=1, help='Number of stacked CNFs.')
parser.add_argument('--time_length', type=float, default=0.5)
parser.add_argument('--train_T', type=eval, default=True)
parser.add_argument("--divergence_fn", type=str, default="brute_force", choices=["brute_force", "approximate"])
parser.add_argument("--nonlinearity", type=str, default="tanh", choices=odefunc.NONLINEARITIES)

parser.add_argument('--solver', type=str, default='dopri5', choices=SOLVERS)
parser.add_argument('--atol', type=float, default=1e-5)
parser.add_argument('--rtol', type=float, default=1e-5)

parser.add_argument('--residual', type=eval, default=False, choices=[True, False])
parser.add_argument('--rademacher', type=eval, default=False, choices=[True, False])
parser.add_argument('--spectral_norm', type=eval, default=False, choices=[True, False])
parser.add_argument('--niters', type=int, default=100000)
parser.add_argument('--batch_size', type=int, default=100)
parser.add_argument('--test_batch_size', type=int, default=1000)
parser.add_argument('--lr', type=float, default=1e-3)
parser.add_argument('--weight_decay', type=float, default=1e-5)

# for the proposed method
parser.add_argument('--std_min', type=float, default=0.0)
parser.add_argument('--std_max', type=float, default=0.1)
parser.add_argument('--std_weight', type=float, default=2)

parser.add_argument('--viz_freq', type=int, default=100)
parser.add_argument('--val_freq', type=int, default=400)
parser.add_argument('--log_freq', type=int, default=10)
parser.add_argument('--gpu', type=int, default=0)
# args = parser.parse_args()
args, unknown = parser.parse_known_args()

# %%
# logger
args.data = "microgel_multiclass"
save_path = './results/' + args.data + '/SoftFlow'
utils.makedirs(save_path)

device = torch.device('cuda:' + str(args.gpu) if torch.cuda.is_available() else 'cpu')

# %%
def get_transforms(model):

    def sample_fn(z, logpz=None):
        zeors_std = torch.zeros(z.shape[0], 1).to(z)
        if logpz is not None:
            return model(z, zeors_std, logpz, reverse=True)
        else:
            return model(z, zeors_std, reverse=True)

    def density_fn(x, logpx=None):
        zeors_std = torch.zeros(x.shape[0], 1).to(x)
        if logpx is not None:
            return model(x, zeors_std, logpx, reverse=False)
        else:
            return model(x, zeors_std, reverse=False)

    return sample_fn, density_fn

DATA_add = "/home/staff/azad/deeplearning/pointcloud/PAINT_DiffTemp/Core-shell/"
Type     = ['Microgel_plotter_v1_density', 'Microgel_plotter_v2_solvatochromism']

temperature_list = os.listdir(DATA_add)
temperature_list.sort()
temperature_list.remove('35C')

def get_data():
    idt = random.randint(0,len(temperature_list)-1)
    DATA_list = glob.glob(DATA_add+ temperature_list[idt]+'/'+Type[0]+"/*.3d")
    temperature = int(temperature_list[0][-3:-1])
    indx = random.randint(0,len(DATA_list)-1)
    DATA = pd.read_csv(DATA_list[indx], delimiter = "\t", header=None)
    DATA = DATA.to_numpy()[:,:3]
    DATA -= np.mean(DATA, axis=0) 
    DATA = (DATA-np.min(DATA, axis=0))/(np.max(DATA, axis=0)-np.min(DATA, axis=0)) 
    newrow = [temperature, temperature, temperature]
    DATA = np.vstack([newrow, DATA])

    return DATA



def compute_loss(args, model, batch_size=None):
    if batch_size is None: batch_size = args.batch_size
    x = get_data()


    x = torch.from_numpy(x).type(torch.float32).to(device)
    zero = torch.zeros(x.shape[0], 1).to(x)

    # transform to z
    std = (args.std_max - args.std_min) * torch.rand_like(x[:,0]).view(-1,1) + args.std_min
    eps = torch.randn_like(x) * std
    std_in = std / args.std_max * args.std_weight
#     print(x.shape, std_in.shape, zero.shape)
    z, delta_logp = model(x+eps, std_in, zero)

    # compute log q(z)
    logpz = standard_normal_logprob(z).sum(1, keepdim=True)

    logpx = logpz - delta_logp
    loss = -torch.mean(logpx)
    return loss

# %%
model = build_model_tabular(args, 3).to(device)

optimizer = optim.Adam(model.parameters(), lr=args.lr, weight_decay=args.weight_decay)

time_meter = utils.RunningAverageMeter(0.93)
loss_meter = utils.RunningAverageMeter(0.93)
nfef_meter = utils.RunningAverageMeter(0.93)
nfeb_meter = utils.RunningAverageMeter(0.93)
tt_meter = utils.RunningAverageMeter(0.93)

end = time.time()
best_loss = float('inf')

# %%
LOW = -4
HIGH = 4
def visualize3d(samples, prior_sample, prior_logdensity, n_samples, transform, inverse_transform, memory=100, title1="$x ~ p(x)$", title2="$q(x)$", title3="$x ~ q(x)$", device="cpu", npts = 100):
    ## first one
    fig = plt.figure(figsize=(25,5))
    ax1 = fig.add_subplot(1, 3, 1, projection="3d")
    ax1.scatter(samples[:, 0], samples[:, 1], samples[:, 2], s=1, c='b', marker="s", facecolor="red", lw=0, alpha=1)
    ax1.set_xlabel('X')
    ax1.set_ylabel('Y')
    ax1.set_zlabel('Z')
    ax1.set_title(title1)
    
    ## second one
    side = np.linspace(LOW, HIGH, npts)
    xx, yy, zz = np.meshgrid(side, side, side)
    memory=100
    x = np.hstack([xx.reshape(-1, 1), yy.reshape(-1, 1), zz.reshape(-1, 1)])
    x = torch.from_numpy(x).type(torch.float32).to(device)
    zeros = torch.zeros(x.shape[0], 1).to(x)

    z, delta_logp = [], []
    inds = torch.arange(0, x.shape[0]).to(torch.int64)
    for ii in torch.split(inds, int(memory**2)):
        z_, delta_logp_ = inverse_transform(x[ii], zeros[ii])
        z.append(z_)
        delta_logp.append(delta_logp_)
    z = torch.cat(z, 0)
    delta_logp = torch.cat(delta_logp, 0)

    logpz = prior_logdensity(z).view(z.shape[0], -1).sum(1, keepdim=True)  # logp(z)
    logpx = logpz - delta_logp

    px = np.exp(logpx.detach().cpu().numpy()).reshape(npts, npts,npts)
    ax = fig.add_subplot(1, 3, 2)
    ax.imshow(px[:,:,1])
    ax.set_title(title2)
    
    ## Third one
    z = prior_sample(n_samples, 3).type(torch.float32).to(device)
    zk = []
    inds = torch.arange(0, z.shape[0]).to(torch.int64)
    for ii in torch.split(inds, int(memory**2)):
        zk.append(transform(z[ii]))

    zk = torch.cat(zk, 0).detach().cpu().numpy()

    ax1 = fig.add_subplot(1, 3, 3, projection="3d")
    ax1.scatter(zk[:, 0], zk[:, 1], zk[:, 2], s=1, c='r', marker="s", facecolor="red", lw=0, alpha=1)
    ax1.set_xlabel('X')
    ax1.set_ylabel('Y')
    ax1.set_zlabel('Z')
    ax1.set_title(title3)

# %%
model.train()
for itr in range(1, args.niters + 1):
    optimizer.zero_grad()

    loss = compute_loss(args, model)
    

    loss_meter.update(loss.item())

    total_time = count_total_time(model)
    nfe_forward = count_nfe(model)

    loss.backward()
    optimizer.step()

    nfe_total = count_nfe(model)
    nfe_backward = nfe_total - nfe_forward
    nfef_meter.update(nfe_forward)
    nfeb_meter.update(nfe_backward)

    time_meter.update(time.time() - end)
    tt_meter.update(total_time)

    log_message = (
        'Iter {:04d} | Time {:.4f}({:.4f}) | Loss {:.6f}({:.6f}) | NFE Forward {:.0f}({:.1f})'
        ' | NFE Backward {:.0f}({:.1f}) | CNF Time {:.4f}({:.4f})'.format(
            itr, time_meter.val, time_meter.avg, loss_meter.val, loss_meter.avg, nfef_meter.val, nfef_meter.avg,
            nfeb_meter.val, nfeb_meter.avg, tt_meter.val, tt_meter.avg
        )
    )

    print(log_message)
    
    if itr % args.val_freq == 0 or itr == args.niters:
        with torch.no_grad():
            model.eval()
            test_loss = compute_loss(args, model, batch_size=args.test_batch_size)
            test_nfe = count_nfe(model)
            log_message = '[TEST] Iter {:04d} | Test Loss {:.6f} | NFE {:.0f}'.format(itr, test_loss, test_nfe)
            print(log_message)

            if test_loss.item() < best_loss:
                best_loss = test_loss.item()
                utils.makedirs(save_path)
                torch.save({
                    'args': args,
                    'state_dict': model.state_dict(),
                }, os.path.join(save_path, 'checkpt.pth'))
            model.train()

    if itr % args.viz_freq == 0:
        with torch.no_grad():
            model.eval()
#             p_samples = toy_data.inf_train_gen(args.data, batch_size=2000)
            p_samples = get_data()

            sample_fn, density_fn = get_transforms(model)
            p_samples = p_samples[1:]
            plt.figure(figsize=(9, 3))
            visualize3d(p_samples, torch.randn, standard_normal_logprob, p_samples.shape[0], sample_fn,density_fn, device=device)
            fig_filename = os.path.join(save_path, 'figs', '{:04d}.jpg'.format(itr))
            utils.makedirs(os.path.dirname(fig_filename))
            plt.savefig(fig_filename, format='png')#, dpi=1200)
            plt.close()
            model.train()

    end = time.time()

print('Training has finished.')
# Out:
# Iter 0001 | Time 0.7457(0.7457) | Loss 3.460724(3.460724) | NFE Forward 20(20.0) | NFE Backward 26(26.0) | CNF Time 0.5000(0.5000)
# Iter 0002 | Time 0.2229(0.7091) | Loss 3.442682(3.459461) | NFE Forward 26(20.4) | NFE Backward 26(26.0) | CNF Time 0.5000(0.5000)
# Iter 0003 | Time 0.2207(0.6749) | Loss 3.563042(3.466712) | NFE Forward 26(20.8) | NFE Backward 26(26.0) | CNF Time 0.5000(0.5000)
# Iter 0004 | Time 0.1727(0.6397) | Loss 3.287864(3.454193) | NFE Forward 20(20.8) | NFE Backward 20(25.6) | CNF Time 0.5000(0.5000)
# Iter 0005 | Time 0.1730(0.6071) | Loss 3.264372(3.440905) | NFE Forward 20(20.7) | NFE Backward 20(25.2) | CNF Time 0.5000(0.5000)
# Iter 0006 | Time 0.2223(0.5801) | Loss 3.204510(3.424358) | NFE Forward 26(21.1) | NFE Backward 26(25.2) | CNF Time 0.5000(0.5000)
# Iter 0007 | Time 0.2027(0.5537) | Loss 3.349168(3.419094) | NFE Forward 20(21.0) | NFE Backward 26(25.3) | CNF Time 0.5000(0.5000)
# Iter 0008 | Time 0.1728(0.5270) | Loss 3.329600(3.412830) | NFE Forward 20(20.9) | NFE Backward 20(24.9) | CNF Time 0.5000(0.5000)
# Iter 0009 | Time 0.2022(0.5043) | Loss 3.188444(3.397123) | NFE Forward 20(20.9) | NFE Backward 26(25.0) | CNF Time 0.5000(0.5000)
# Iter 0010 | Time 0.2041(0.4833) | Loss 3.248688(3.386732) | NFE Forward 20(20.8) | NFE Backward 26(25.1) | CNF Time 0.5000(0.5000)
# Iter 0011 | Time 0.2011(0.4635) | Loss 3.119313(3.368013) | NFE Forward 20(20.7) | NFE Backward 26(25.1) | CNF Time 0.5000(0.5000)
# Iter 0012 | Time 0.2080(0.4456) | Loss 3.239533(3.359019) | NFE Forward 26(21.1) | NFE Backward 26(25.2) | CNF Time 0.5000(0.5000)
# Iter 0013 | Time 0.1727(0.4265) | Loss 3.210000(3.348588) | NFE Forward 20(21.0) | NFE Backward 20(24.8) | CNF Time 0.5000(0.5000)
# Iter 0014 | Time 0.1729(0.4088) | Loss 3.096104(3.330914) | NFE Forward 20(21.0) | NFE Backward 20(24.5) | CNF Time 0.5000(0.5000)
# Iter 0015 | Time 0.2222(0.3957) | Loss 3.089858(3.314040) | NFE Forward 26(21.3) | NFE Backward 26(24.6) | CNF Time 0.5000(0.5000)
# Iter 0016 | Time 0.2014(0.3821) | Loss 3.073344(3.297191) | NFE Forward 20(21.2) | NFE Backward 26(24.7) | CNF Time 0.5000(0.5000)
# Iter 0017 | Time 0.2215(0.3709) | Loss 3.031915(3.278622) | NFE Forward 26(21.6) | NFE Backward 26(24.8) | CNF Time 0.5000(0.5000)
# Iter 0018 | Time 0.2167(0.3601) | Loss 3.282008(3.278859) | NFE Forward 26(21.9) | NFE Backward 26(24.9) | CNF Time 0.5000(0.5000)
# Iter 0019 | Time 0.2217(0.3504) | Loss 2.999045(3.259272) | NFE Forward 26(22.2) | NFE Backward 26(25.0) | CNF Time 0.5000(0.5000)
# Iter 0020 | Time 0.2161(0.3410) | Loss 3.402937(3.269329) | NFE Forward 26(22.4) | NFE Backward 26(25.0) | CNF Time 0.5000(0.5000)
# Iter 0021 | Time 0.2216(0.3326) | Loss 2.990110(3.249783) | NFE Forward 26(22.7) | NFE Backward 26(25.1) | CNF Time 0.5000(0.5000)
# Iter 0022 | Time 0.2233(0.3250) | Loss 2.960530(3.229536) | NFE Forward 26(22.9) | NFE Backward 26(25.2) | CNF Time 0.5000(0.5000)
# Iter 0023 | Time 0.2220(0.3178) | Loss 3.157032(3.224460) | NFE Forward 26(23.1) | NFE Backward 26(25.2) | CNF Time 0.5000(0.5000)
# Iter 0024 | Time 0.2241(0.3112) | Loss 3.007936(3.209304) | NFE Forward 26(23.3) | NFE Backward 26(25.3) | CNF Time 0.5000(0.5000)
# Iter 0025 | Time 0.2189(0.3048) | Loss 3.213106(3.209570) | NFE Forward 26(23.5) | NFE Backward 26(25.3) | CNF Time 0.5000(0.5000)
# Iter 0026 | Time 0.2232(0.2990) | Loss 2.888897(3.187123) | NFE Forward 26(23.7) | NFE Backward 26(25.4) | CNF Time 0.5000(0.5000)
# Iter 0027 | Time 0.2213(0.2936) | Loss 2.901136(3.167104) | NFE Forward 26(23.9) | NFE Backward 26(25.4) | CNF Time 0.5000(0.5000)
# Iter 0028 | Time 0.2227(0.2886) | Loss 2.853436(3.145147) | NFE Forward 26(24.0) | NFE Backward 26(25.5) | CNF Time 0.5000(0.5000)
# Iter 0029 | Time 0.2231(0.2841) | Loss 2.977272(3.133396) | NFE Forward 26(24.1) | NFE Backward 26(25.5) | CNF Time 0.5000(0.5000)
# Iter 0030 | Time 0.2236(0.2798) | Loss 2.824555(3.111777) | NFE Forward 26(24.3) | NFE Backward 26(25.5) | CNF Time 0.5000(0.5000)
# Iter 0031 | Time 0.2215(0.2757) | Loss 2.935510(3.099438) | NFE Forward 26(24.4) | NFE Backward 26(25.6) | CNF Time 0.5000(0.5000)
# Iter 0032 | Time 0.2225(0.2720) | Loss 2.940358(3.088303) | NFE Forward 26(24.5) | NFE Backward 26(25.6) | CNF Time 0.5000(0.5000)
# Iter 0033 | Time 0.2230(0.2686) | Loss 2.915354(3.076196) | NFE Forward 26(24.6) | NFE Backward 26(25.6) | CNF Time 0.5000(0.5000)
# Iter 0034 | Time 0.2214(0.2653) | Loss 2.805192(3.057226) | NFE Forward 26(24.7) | NFE Backward 26(25.6) | CNF Time 0.5000(0.5000)
# Iter 0035 | Time 0.2231(0.2623) | Loss 2.792269(3.038679) | NFE Forward 26(24.8) | NFE Backward 26(25.7) | CNF Time 0.5000(0.5000)
# Iter 0036 | Time 0.2235(0.2596) | Loss 2.932471(3.031244) | NFE Forward 26(24.9) | NFE Backward 26(25.7) | CNF Time 0.5000(0.5000)
# Iter 0037 | Time 0.2237(0.2571) | Loss 2.971861(3.027088) | NFE Forward 26(25.0) | NFE Backward 26(25.7) | CNF Time 0.5000(0.5000)
# Iter 0038 | Time 0.2239(0.2548) | Loss 2.845105(3.014349) | NFE Forward 26(25.0) | NFE Backward 26(25.7) | CNF Time 0.5000(0.5000)
# Iter 0039 | Time 0.2239(0.2526) | Loss 2.937856(3.008994) | NFE Forward 26(25.1) | NFE Backward 26(25.8) | CNF Time 0.5000(0.5000)
# Iter 0040 | Time 0.2242(0.2506) | Loss 2.803093(2.994581) | NFE Forward 26(25.2) | NFE Backward 26(25.8) | CNF Time 0.5000(0.5000)
# Iter 0041 | Time 0.2234(0.2487) | Loss 2.634859(2.969401) | NFE Forward 26(25.2) | NFE Backward 26(25.8) | CNF Time 0.5000(0.5000)
# Iter 0042 | Time 0.2228(0.2469) | Loss 2.764045(2.955026) | NFE Forward 26(25.3) | NFE Backward 26(25.8) | CNF Time 0.5000(0.5000)
# Iter 0043 | Time 0.2229(0.2452) | Loss 2.775912(2.942488) | NFE Forward 26(25.3) | NFE Backward 26(25.8) | CNF Time 0.5000(0.5000)
# Iter 0044 | Time 0.2231(0.2437) | Loss 2.777344(2.930928) | NFE Forward 26(25.4) | NFE Backward 26(25.8) | CNF Time 0.5000(0.5000)
# Iter 0045 | Time 0.2217(0.2421) | Loss 2.719235(2.916109) | NFE Forward 26(25.4) | NFE Backward 26(25.8) | CNF Time 0.5000(0.5000)
# Iter 0046 | Time 0.2363(0.2417) | Loss 2.791174(2.907364) | NFE Forward 32(25.9) | NFE Backward 26(25.9) | CNF Time 0.5000(0.5000)
# Iter 0047 | Time 0.2424(0.2418) | Loss 2.656800(2.889824) | NFE Forward 32(26.3) | NFE Backward 26(25.9) | CNF Time 0.5000(0.5000)
# Iter 0048 | Time 0.2394(0.2416) | Loss 2.589189(2.868780) | NFE Forward 32(26.7) | NFE Backward 26(25.9) | CNF Time 0.5000(0.5000)
# Iter 0049 | Time 0.2694(0.2436) | Loss 2.506332(2.843408) | NFE Forward 32(27.1) | NFE Backward 32(26.3) | CNF Time 0.5000(0.5000)
# Iter 0050 | Time 0.2728(0.2456) | Loss 2.523247(2.820997) | NFE Forward 32(27.4) | NFE Backward 32(26.7) | CNF Time 0.5000(0.5000)
# Iter 0051 | Time 0.2658(0.2470) | Loss 2.942225(2.829483) | NFE Forward 32(27.7) | NFE Backward 32(27.1) | CNF Time 0.5000(0.5000)
# Iter 0052 | Time 0.2696(0.2486) | Loss 2.411266(2.800208) | NFE Forward 32(28.0) | NFE Backward 32(27.4) | CNF Time 0.5000(0.5000)
# Iter 0053 | Time 0.2664(0.2498) | Loss 2.633649(2.788549) | NFE Forward 32(28.3) | NFE Backward 32(27.7) | CNF Time 0.5000(0.5000)
# Iter 0054 | Time 0.2705(0.2513) | Loss 2.501452(2.768452) | NFE Forward 32(28.6) | NFE Backward 32(28.0) | CNF Time 0.5000(0.5000)
# Iter 0055 | Time 0.2680(0.2525) | Loss 2.476507(2.748016) | NFE Forward 32(28.8) | NFE Backward 32(28.3) | CNF Time 0.5000(0.5000)
# Iter 0056 | Time 0.2695(0.2536) | Loss 2.236948(2.712241) | NFE Forward 32(29.0) | NFE Backward 32(28.6) | CNF Time 0.5000(0.5000)
# Iter 0057 | Time 0.2719(0.2549) | Loss 2.255081(2.680240) | NFE Forward 32(29.2) | NFE Backward 32(28.8) | CNF Time 0.5000(0.5000)
# Iter 0058 | Time 0.2723(0.2561) | Loss 2.310406(2.654352) | NFE Forward 32(29.4) | NFE Backward 32(29.0) | CNF Time 0.5000(0.5000)
# Iter 0059 | Time 0.2723(0.2573) | Loss 2.042954(2.611554) | NFE Forward 32(29.6) | NFE Backward 32(29.2) | CNF Time 0.5000(0.5000)
# Iter 0060 | Time 0.2920(0.2597) | Loss 1.952633(2.565429) | NFE Forward 38(30.2) | NFE Backward 32(29.4) | CNF Time 0.5000(0.5000)
# Iter 0061 | Time 0.2927(0.2620) | Loss 2.188139(2.539019) | NFE Forward 38(30.7) | NFE Backward 32(29.6) | CNF Time 0.5000(0.5000)
# Iter 0062 | Time 0.2836(0.2635) | Loss 2.236822(2.517865) | NFE Forward 38(31.3) | NFE Backward 32(29.8) | CNF Time 0.5000(0.5000)
# Iter 0063 | Time 0.2901(0.2654) | Loss 1.980335(2.480238) | NFE Forward 38(31.7) | NFE Backward 32(29.9) | CNF Time 0.5000(0.5000)
# Iter 0064 | Time 0.2898(0.2671) | Loss 1.938774(2.442336) | NFE Forward 38(32.2) | NFE Backward 32(30.1) | CNF Time 0.5000(0.5000)
# Iter 0065 | Time 0.2843(0.2683) | Loss 2.073342(2.416506) | NFE Forward 38(32.6) | NFE Backward 32(30.2) | CNF Time 0.5000(0.5000)
# Iter 0066 | Time 0.2899(0.2698) | Loss 1.671354(2.364345) | NFE Forward 38(33.0) | NFE Backward 32(30.3) | CNF Time 0.5000(0.5000)
# Iter 0067 | Time 0.2848(0.2709) | Loss 2.002984(2.339050) | NFE Forward 38(33.3) | NFE Backward 32(30.5) | CNF Time 0.5000(0.5000)
# Iter 0068 | Time 0.2902(0.2722) | Loss 1.762262(2.298675) | NFE Forward 38(33.6) | NFE Backward 32(30.6) | CNF Time 0.5000(0.5000)
# Iter 0069 | Time 0.2890(0.2734) | Loss 1.536389(2.245315) | NFE Forward 38(33.9) | NFE Backward 32(30.7) | CNF Time 0.5000(0.5000)
# Iter 0070 | Time 0.2919(0.2747) | Loss 1.620071(2.201548) | NFE Forward 38(34.2) | NFE Backward 32(30.8) | CNF Time 0.5000(0.5000)
# Iter 0071 | Time 0.2850(0.2754) | Loss 1.820957(2.174906) | NFE Forward 38(34.5) | NFE Backward 32(30.8) | CNF Time 0.5000(0.5000)
# Iter 0072 | Time 0.3217(0.2786) | Loss 1.617091(2.135859) | NFE Forward 38(34.7) | NFE Backward 38(31.3) | CNF Time 0.5000(0.5000)
# Iter 0073 | Time 0.3208(0.2816) | Loss 1.282403(2.076117) | NFE Forward 38(35.0) | NFE Backward 38(31.8) | CNF Time 0.5000(0.5000)
# Iter 0074 | Time 0.3397(0.2857) | Loss 1.247259(2.018097) | NFE Forward 44(35.6) | NFE Backward 38(32.2) | CNF Time 0.5000(0.5000)
# Iter 0075 | Time 0.3382(0.2893) | Loss 1.401477(1.974934) | NFE Forward 44(36.2) | NFE Backward 38(32.6) | CNF Time 0.5000(0.5000)
# Iter 0076 | Time 0.3376(0.2927) | Loss 0.962930(1.904094) | NFE Forward 44(36.7) | NFE Backward 38(33.0) | CNF Time 0.5000(0.5000)
# Iter 0077 | Time 0.3393(0.2960) | Loss 1.365080(1.866363) | NFE Forward 44(37.2) | NFE Backward 38(33.4) | CNF Time 0.5000(0.5000)
# Iter 0078 | Time 0.3317(0.2985) | Loss 1.916446(1.869869) | NFE Forward 44(37.7) | NFE Backward 38(33.7) | CNF Time 0.5000(0.5000)
# Iter 0079 | Time 0.3681(0.3034) | Loss 1.225708(1.824777) | NFE Forward 44(38.2) | NFE Backward 44(34.4) | CNF Time 0.5000(0.5000)
# Iter 0080 | Time 0.3685(0.3079) | Loss 1.287089(1.787139) | NFE Forward 44(38.6) | NFE Backward 44(35.1) | CNF Time 0.5000(0.5000)
# Iter 0081 | Time 0.3886(0.3136) | Loss 1.772459(1.786112) | NFE Forward 44(38.9) | NFE Backward 50(36.1) | CNF Time 0.5000(0.5000)
# Iter 0082 | Time 0.3667(0.3173) | Loss 1.353453(1.755825) | NFE Forward 44(39.3) | NFE Backward 44(36.7) | CNF Time 0.5000(0.5000)
# Iter 0083 | Time 0.3613(0.3204) | Loss 1.477126(1.736316) | NFE Forward 44(39.6) | NFE Backward 44(37.2) | CNF Time 0.5000(0.5000)
# Iter 0084 | Time 0.3678(0.3237) | Loss 1.053119(1.688493) | NFE Forward 44(39.9) | NFE Backward 44(37.7) | CNF Time 0.5000(0.5000)
# Iter 0085 | Time 0.3660(0.3266) | Loss 1.026607(1.642161) | NFE Forward 44(40.2) | NFE Backward 44(38.1) | CNF Time 0.5000(0.5000)
# Iter 0086 | Time 0.3662(0.3294) | Loss 0.849783(1.586694) | NFE Forward 44(40.5) | NFE Backward 44(38.5) | CNF Time 0.5000(0.5000)
# Iter 0087 | Time 0.3654(0.3319) | Loss 0.919767(1.540009) | NFE Forward 44(40.7) | NFE Backward 44(38.9) | CNF Time 0.5000(0.5000)
# Iter 0088 | Time 0.3883(0.3359) | Loss 1.488940(1.536434) | NFE Forward 44(41.0) | NFE Backward 50(39.7) | CNF Time 0.5000(0.5000)
# Iter 0089 | Time 0.3951(0.3400) | Loss 0.874917(1.490128) | NFE Forward 44(41.2) | NFE Backward 50(40.4) | CNF Time 0.5000(0.5000)
# Iter 0090 | Time 0.3988(0.3441) | Loss 0.762202(1.439173) | NFE Forward 44(41.4) | NFE Backward 50(41.1) | CNF Time 0.5000(0.5000)
# Iter 0091 | Time 0.3664(0.3457) | Loss 1.324314(1.431133) | NFE Forward 44(41.6) | NFE Backward 44(41.3) | CNF Time 0.5000(0.5000)
# Iter 0092 | Time 0.3950(0.3492) | Loss 1.037186(1.403557) | NFE Forward 44(41.7) | NFE Backward 50(41.9) | CNF Time 0.5000(0.5000)
# Iter 0093 | Time 0.3593(0.3499) | Loss 1.694798(1.423944) | NFE Forward 44(41.9) | NFE Backward 44(42.0) | CNF Time 0.5000(0.5000)
# Iter 0094 | Time 0.3666(0.3510) | Loss 1.132680(1.403555) | NFE Forward 44(42.0) | NFE Backward 44(42.2) | CNF Time 0.5000(0.5000)
# Iter 0095 | Time 0.3659(0.3521) | Loss 1.249414(1.392765) | NFE Forward 44(42.2) | NFE Backward 44(42.3) | CNF Time 0.5000(0.5000)
# Iter 0096 | Time 0.3656(0.3530) | Loss 0.985625(1.364266) | NFE Forward 44(42.3) | NFE Backward 44(42.4) | CNF Time 0.5000(0.5000)
# Iter 0097 | Time 0.3699(0.3542) | Loss 0.958283(1.335847) | NFE Forward 44(42.4) | NFE Backward 44(42.5) | CNF Time 0.5000(0.5000)
# Iter 0098 | Time 0.3402(0.3532) | Loss 0.566928(1.282023) | NFE Forward 44(42.5) | NFE Backward 38(42.2) | CNF Time 0.5000(0.5000)
# Iter 0099 | Time 0.3733(0.3546) | Loss 0.521556(1.228790) | NFE Forward 38(42.2) | NFE Backward 44(42.3) | CNF Time 0.5000(0.5000)
# Iter 0100 | Time 0.3715(0.3558) | Loss 0.845528(1.201962) | NFE Forward 44(42.3) | NFE Backward 44(42.5) | CNF Time 0.5000(0.5000)
# Iter 0101 | Time 0.3710(0.3569) | Loss 0.836557(1.176383) | NFE Forward 44(42.5) | NFE Backward 44(42.6) | CNF Time 0.5000(0.5000)
# Iter 0102 | Time 0.3653(0.3575) | Loss 0.680829(1.141694) | NFE Forward 44(42.6) | NFE Backward 44(42.7) | CNF Time 0.5000(0.5000)
# Iter 0103 | Time 0.3660(0.3581) | Loss 0.667542(1.108504) | NFE Forward 44(42.7) | NFE Backward 44(42.8) | CNF Time 0.5000(0.5000)
# Iter 0104 | Time 0.3637(0.3585) | Loss 0.750788(1.083464) | NFE Forward 44(42.8) | NFE Backward 44(42.8) | CNF Time 0.5000(0.5000)
# Iter 0105 | Time 0.3688(0.3592) | Loss 0.658150(1.053692) | NFE Forward 44(42.8) | NFE Backward 44(42.9) | CNF Time 0.5000(0.5000)
# Iter 0106 | Time 0.3404(0.3579) | Loss 0.287163(1.000035) | NFE Forward 38(42.5) | NFE Backward 38(42.6) | CNF Time 0.5000(0.5000)
# Iter 0107 | Time 0.3684(0.3586) | Loss 0.324949(0.952779) | NFE Forward 44(42.6) | NFE Backward 44(42.7) | CNF Time 0.5000(0.5000)
# Iter 0108 | Time 0.3673(0.3592) | Loss 0.717390(0.936302) | NFE Forward 44(42.7) | NFE Backward 44(42.8) | CNF Time 0.5000(0.5000)
# Iter 0109 | Time 0.3663(0.3597) | Loss 0.164350(0.882265) | NFE Forward 44(42.8) | NFE Backward 44(42.9) | CNF Time 0.5000(0.5000)
# Iter 0110 | Time 0.3675(0.3603) | Loss 0.478348(0.853991) | NFE Forward 44(42.9) | NFE Backward 44(42.9) | CNF Time 0.5000(0.5000)
# Iter 0111 | Time 0.3608(0.3603) | Loss 0.884266(0.856110) | NFE Forward 44(43.0) | NFE Backward 44(43.0) | CNF Time 0.5000(0.5000)
# Iter 0112 | Time 0.3690(0.3609) | Loss 0.538708(0.833892) | NFE Forward 44(43.0) | NFE Backward 44(43.1) | CNF Time 0.5000(0.5000)
# Iter 0113 | Time 0.3675(0.3614) | Loss 0.425693(0.805318) | NFE Forward 44(43.1) | NFE Backward 44(43.1) | CNF Time 0.5000(0.5000)
# Iter 0114 | Time 0.3706(0.3620) | Loss 0.924631(0.813670) | NFE Forward 44(43.2) | NFE Backward 44(43.2) | CNF Time 0.5000(0.5000)
# Iter 0115 | Time 0.3693(0.3625) | Loss 0.269099(0.775550) | NFE Forward 44(43.2) | NFE Backward 44(43.3) | CNF Time 0.5000(0.5000)
# Iter 0116 | Time 0.3605(0.3624) | Loss 0.792061(0.776706) | NFE Forward 44(43.3) | NFE Backward 44(43.3) | CNF Time 0.5000(0.5000)
# Iter 0117 | Time 0.3687(0.3628) | Loss 0.230536(0.738474) | NFE Forward 44(43.3) | NFE Backward 44(43.4) | CNF Time 0.5000(0.5000)
# Iter 0118 | Time 0.3950(0.3651) | Loss 0.355764(0.711684) | NFE Forward 44(43.4) | NFE Backward 44(43.4) | CNF Time 0.5000(0.5000)
# Iter 0119 | Time 0.3701(0.3654) | Loss 0.650403(0.707394) | NFE Forward 44(43.4) | NFE Backward 44(43.4) | CNF Time 0.5000(0.5000)
# Iter 0120 | Time 0.3622(0.3652) | Loss 0.618415(0.701166) | NFE Forward 44(43.5) | NFE Backward 44(43.5) | CNF Time 0.5000(0.5000)
# Iter 0121 | Time 0.3684(0.3654) | Loss 0.080948(0.657751) | NFE Forward 44(43.5) | NFE Backward 44(43.5) | CNF Time 0.5000(0.5000)
# Iter 0122 | Time 0.3586(0.3649) | Loss 0.393426(0.639248) | NFE Forward 44(43.5) | NFE Backward 44(43.6) | CNF Time 0.5000(0.5000)
# Iter 0123 | Time 0.3974(0.3672) | Loss 0.143066(0.604515) | NFE Forward 44(43.6) | NFE Backward 44(43.6) | CNF Time 0.5000(0.5000)
# Iter 0124 | Time 0.3666(0.3672) | Loss 0.406662(0.590666) | NFE Forward 44(43.6) | NFE Backward 44(43.6) | CNF Time 0.5000(0.5000)
# Iter 0125 | Time 0.4002(0.3695) | Loss -0.017061(0.548125) | NFE Forward 38(43.2) | NFE Backward 50(44.1) | CNF Time 0.5000(0.5000)
# Iter 0126 | Time 0.3656(0.3692) | Loss 0.558068(0.548821) | NFE Forward 44(43.3) | NFE Backward 44(44.1) | CNF Time 0.5000(0.5000)
# Iter 0127 | Time 0.3600(0.3686) | Loss 0.619140(0.553743) | NFE Forward 44(43.3) | NFE Backward 44(44.1) | CNF Time 0.5000(0.5000)
# Iter 0128 | Time 0.3665(0.3684) | Loss -0.087883(0.508829) | NFE Forward 44(43.4) | NFE Backward 44(44.1) | CNF Time 0.5000(0.5000)
# Iter 0129 | Time 0.3656(0.3682) | Loss 0.047504(0.476537) | NFE Forward 44(43.4) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0130 | Time 0.3599(0.3676) | Loss 0.249466(0.460642) | NFE Forward 44(43.4) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0131 | Time 0.3603(0.3671) | Loss 0.702270(0.477556) | NFE Forward 44(43.5) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0132 | Time 0.3673(0.3671) | Loss 0.277961(0.463584) | NFE Forward 44(43.5) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0133 | Time 0.3701(0.3673) | Loss 0.191937(0.444569) | NFE Forward 44(43.6) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0134 | Time 0.3691(0.3675) | Loss 0.265467(0.432032) | NFE Forward 44(43.6) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0135 | Time 0.3718(0.3678) | Loss -0.221461(0.386287) | NFE Forward 44(43.6) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0136 | Time 0.3909(0.3694) | Loss 0.157207(0.370252) | NFE Forward 44(43.6) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0137 | Time 0.4060(0.3720) | Loss 0.533091(0.381650) | NFE Forward 50(44.1) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0138 | Time 0.4025(0.3741) | Loss 0.337809(0.378581) | NFE Forward 50(44.5) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0139 | Time 0.4256(0.3777) | Loss 0.892061(0.414525) | NFE Forward 50(44.9) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0140 | Time 0.3954(0.3789) | Loss -0.089274(0.379259) | NFE Forward 44(44.8) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0141 | Time 0.4089(0.3810) | Loss 0.753703(0.405470) | NFE Forward 50(45.2) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0142 | Time 0.3880(0.3815) | Loss 0.122732(0.385678) | NFE Forward 44(45.1) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0143 | Time 0.3729(0.3809) | Loss -0.151143(0.348101) | NFE Forward 44(45.0) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0144 | Time 0.3767(0.3806) | Loss 0.496075(0.358459) | NFE Forward 44(45.0) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0145 | Time 0.3784(0.3805) | Loss 0.798270(0.389246) | NFE Forward 50(45.3) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0146 | Time 0.3683(0.3796) | Loss -0.135791(0.352493) | NFE Forward 44(45.2) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0147 | Time 0.3679(0.3788) | Loss -0.002099(0.327672) | NFE Forward 44(45.1) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0148 | Time 0.3670(0.3780) | Loss -0.087463(0.298612) | NFE Forward 44(45.1) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0149 | Time 0.3666(0.3772) | Loss -0.282354(0.257945) | NFE Forward 44(45.0) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0150 | Time 0.3682(0.3766) | Loss 0.079998(0.245489) | NFE Forward 44(44.9) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0151 | Time 0.3705(0.3761) | Loss -0.390404(0.200976) | NFE Forward 44(44.8) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0152 | Time 0.3633(0.3752) | Loss 0.310039(0.208610) | NFE Forward 44(44.8) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0153 | Time 0.3831(0.3758) | Loss 0.849410(0.253466) | NFE Forward 50(45.2) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0154 | Time 0.3625(0.3749) | Loss 0.742618(0.287707) | NFE Forward 44(45.1) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0155 | Time 0.3892(0.3759) | Loss -0.197313(0.253756) | NFE Forward 50(45.4) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0156 | Time 0.3635(0.3750) | Loss 0.073903(0.241166) | NFE Forward 44(45.3) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0157 | Time 0.3686(0.3745) | Loss -0.475777(0.190980) | NFE Forward 44(45.2) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0158 | Time 0.3923(0.3758) | Loss 0.588040(0.218774) | NFE Forward 50(45.6) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0159 | Time 0.3917(0.3769) | Loss 0.098464(0.210352) | NFE Forward 50(45.9) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0160 | Time 0.3821(0.3773) | Loss 0.907287(0.259138) | NFE Forward 50(46.2) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0161 | Time 0.3689(0.3767) | Loss 0.137296(0.250609) | NFE Forward 44(46.0) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0162 | Time 0.3639(0.3758) | Loss 0.092571(0.239546) | NFE Forward 44(45.9) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0163 | Time 0.3715(0.3755) | Loss -0.017138(0.221578) | NFE Forward 44(45.7) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0164 | Time 0.3708(0.3752) | Loss -0.155304(0.195197) | NFE Forward 44(45.6) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0165 | Time 0.3689(0.3747) | Loss 0.002058(0.181677) | NFE Forward 44(45.5) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0166 | Time 0.3709(0.3744) | Loss -0.412716(0.140069) | NFE Forward 44(45.4) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0167 | Time 0.3917(0.3757) | Loss -0.088323(0.124082) | NFE Forward 50(45.7) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0168 | Time 0.3752(0.3756) | Loss -0.599038(0.073464) | NFE Forward 38(45.2) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0169 | Time 0.3743(0.3755) | Loss -0.461361(0.036026) | NFE Forward 44(45.1) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0170 | Time 0.3819(0.3760) | Loss -0.380276(0.006885) | NFE Forward 44(45.0) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0171 | Time 0.3686(0.3755) | Loss -0.412982(-0.022506) | NFE Forward 44(44.9) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0172 | Time 0.3911(0.3766) | Loss -0.751659(-0.073547) | NFE Forward 50(45.3) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0173 | Time 0.3916(0.3776) | Loss -0.129090(-0.077435) | NFE Forward 50(45.6) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0174 | Time 0.3555(0.3761) | Loss -0.289199(-0.092258) | NFE Forward 50(45.9) | NFE Backward 38(43.6) | CNF Time 0.5000(0.5000)
# Iter 0175 | Time 0.3893(0.3770) | Loss -0.304912(-0.107144) | NFE Forward 50(46.2) | NFE Backward 44(43.6) | CNF Time 0.5000(0.5000)
# Iter 0176 | Time 0.3620(0.3759) | Loss -0.610992(-0.142413) | NFE Forward 50(46.5) | NFE Backward 38(43.2) | CNF Time 0.5000(0.5000)
# Iter 0177 | Time 0.3852(0.3766) | Loss -0.114213(-0.140439) | NFE Forward 50(46.7) | NFE Backward 44(43.3) | CNF Time 0.5000(0.5000)
# Iter 0178 | Time 0.4030(0.3784) | Loss -0.744990(-0.182758) | NFE Forward 50(47.0) | NFE Backward 44(43.3) | CNF Time 0.5000(0.5000)
# Iter 0179 | Time 0.3895(0.3792) | Loss -0.892204(-0.232419) | NFE Forward 50(47.2) | NFE Backward 44(43.4) | CNF Time 0.5000(0.5000)
# Iter 0180 | Time 0.3590(0.3778) | Loss -0.745597(-0.268342) | NFE Forward 50(47.4) | NFE Backward 38(43.0) | CNF Time 0.5000(0.5000)
# Iter 0181 | Time 0.3573(0.3764) | Loss -0.544329(-0.287661) | NFE Forward 50(47.6) | NFE Backward 38(42.6) | CNF Time 0.5000(0.5000)
# Iter 0182 | Time 0.3619(0.3754) | Loss -0.546653(-0.305790) | NFE Forward 50(47.7) | NFE Backward 38(42.3) | CNF Time 0.5000(0.5000)
# Iter 0183 | Time 0.3929(0.3766) | Loss -0.562333(-0.323748) | NFE Forward 50(47.9) | NFE Backward 44(42.4) | CNF Time 0.5000(0.5000)
# Iter 0184 | Time 0.4215(0.3797) | Loss -0.832274(-0.359345) | NFE Forward 50(48.0) | NFE Backward 50(43.0) | CNF Time 0.5000(0.5000)
# Iter 0185 | Time 0.3922(0.3806) | Loss -0.925583(-0.398982) | NFE Forward 50(48.2) | NFE Backward 44(43.0) | CNF Time 0.5000(0.5000)
# Iter 0186 | Time 0.4236(0.3836) | Loss -0.964609(-0.438576) | NFE Forward 50(48.3) | NFE Backward 50(43.5) | CNF Time 0.5000(0.5000)
# Iter 0187 | Time 0.3886(0.3840) | Loss -0.143953(-0.417952) | NFE Forward 50(48.4) | NFE Backward 44(43.6) | CNF Time 0.5000(0.5000)
# Iter 0188 | Time 0.3861(0.3841) | Loss -0.811673(-0.445512) | NFE Forward 50(48.5) | NFE Backward 44(43.6) | CNF Time 0.5000(0.5000)
# Iter 0189 | Time 0.4152(0.3863) | Loss -0.015033(-0.415379) | NFE Forward 50(48.6) | NFE Backward 50(44.0) | CNF Time 0.5000(0.5000)
# Iter 0190 | Time 0.3895(0.3865) | Loss -0.540698(-0.424151) | NFE Forward 50(48.7) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0191 | Time 0.3997(0.3874) | Loss -0.445047(-0.425614) | NFE Forward 50(48.8) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0192 | Time 0.4220(0.3899) | Loss -0.929731(-0.460902) | NFE Forward 50(48.9) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0193 | Time 0.3926(0.3900) | Loss -0.232660(-0.444925) | NFE Forward 50(49.0) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0194 | Time 0.3908(0.3901) | Loss -1.064582(-0.488301) | NFE Forward 50(49.0) | NFE Backward 44(44.0) | CNF Time 0.5000(0.5000)
# Iter 0195 | Time 0.4211(0.3923) | Loss -0.824873(-0.511861) | NFE Forward 50(49.1) | NFE Backward 50(44.4) | CNF Time 0.5000(0.5000)
# Iter 0196 | Time 0.4415(0.3957) | Loss 0.032769(-0.473737) | NFE Forward 50(49.2) | NFE Backward 56(45.3) | CNF Time 0.5000(0.5000)
# Iter 0197 | Time 0.4218(0.3975) | Loss -0.813696(-0.497534) | NFE Forward 50(49.2) | NFE Backward 50(45.6) | CNF Time 0.5000(0.5000)
# Iter 0198 | Time 0.4175(0.3989) | Loss -1.186307(-0.545748) | NFE Forward 50(49.3) | NFE Backward 50(45.9) | CNF Time 0.5000(0.5000)
# Iter 0199 | Time 0.4215(0.4005) | Loss -0.402465(-0.535718) | NFE Forward 50(49.3) | NFE Backward 50(46.2) | CNF Time 0.5000(0.5000)
# Iter 0200 | Time 0.4177(0.4017) | Loss -1.157913(-0.579272) | NFE Forward 50(49.4) | NFE Backward 50(46.4) | CNF Time 0.5000(0.5000)
# Iter 0201 | Time 0.4288(0.4036) | Loss -1.039749(-0.611505) | NFE Forward 44(49.0) | NFE Backward 50(46.7) | CNF Time 0.5000(0.5000)
# Iter 0202 | Time 0.3793(0.4019) | Loss 0.393420(-0.541161) | NFE Forward 50(49.1) | NFE Backward 44(46.5) | CNF Time 0.5000(0.5000)
# Iter 0203 | Time 0.5221(0.4103) | Loss -0.688020(-0.551441) | NFE Forward 50(49.1) | NFE Backward 50(46.8) | CNF Time 0.5000(0.5000)
# Iter 0204 | Time 0.4298(0.4117) | Loss -0.617762(-0.556083) | NFE Forward 50(49.2) | NFE Backward 50(47.0) | CNF Time 0.5000(0.5000)
# Iter 0205 | Time 0.4480(0.4142) | Loss -0.293447(-0.537699) | NFE Forward 50(49.3) | NFE Backward 56(47.6) | CNF Time 0.5000(0.5000)
# Iter 0206 | Time 0.4172(0.4144) | Loss -1.053090(-0.573776) | NFE Forward 50(49.3) | NFE Backward 50(47.8) | CNF Time 0.5000(0.5000)
# Iter 0207 | Time 0.4152(0.4145) | Loss 0.161591(-0.522300) | NFE Forward 50(49.4) | NFE Backward 50(47.9) | CNF Time 0.5000(0.5000)
# Iter 0208 | Time 0.4439(0.4165) | Loss -0.426790(-0.515615) | NFE Forward 50(49.4) | NFE Backward 56(48.5) | CNF Time 0.5000(0.5000)
# Iter 0209 | Time 0.3891(0.4146) | Loss -1.431778(-0.579746) | NFE Forward 44(49.0) | NFE Backward 44(48.2) | CNF Time 0.5000(0.5000)
# Iter 0210 | Time 0.4277(0.4155) | Loss -0.007500(-0.539689) | NFE Forward 50(49.1) | NFE Backward 50(48.3) | CNF Time 0.5000(0.5000)
# Iter 0211 | Time 0.4502(0.4180) | Loss -0.524655(-0.538637) | NFE Forward 50(49.2) | NFE Backward 56(48.8) | CNF Time 0.5000(0.5000)
# Iter 0212 | Time 0.4503(0.4202) | Loss -0.454695(-0.532761) | NFE Forward 50(49.2) | NFE Backward 56(49.4) | CNF Time 0.5000(0.5000)
# Iter 0213 | Time 0.4193(0.4202) | Loss -0.867474(-0.556191) | NFE Forward 50(49.3) | NFE Backward 50(49.4) | CNF Time 0.5000(0.5000)
# Iter 0214 | Time 0.3918(0.4182) | Loss -0.623707(-0.560917) | NFE Forward 50(49.3) | NFE Backward 44(49.0) | CNF Time 0.5000(0.5000)
# Iter 0215 | Time 0.4205(0.4183) | Loss -1.365595(-0.617244) | NFE Forward 50(49.4) | NFE Backward 50(49.1) | CNF Time 0.5000(0.5000)
# Iter 0216 | Time 0.3880(0.4162) | Loss -0.035413(-0.576516) | NFE Forward 50(49.4) | NFE Backward 44(48.7) | CNF Time 0.5000(0.5000)
# Iter 0217 | Time 0.3823(0.4138) | Loss 0.059238(-0.532013) | NFE Forward 50(49.5) | NFE Backward 44(48.4) | CNF Time 0.5000(0.5000)
# Iter 0218 | Time 0.4399(0.4157) | Loss -0.148293(-0.505153) | NFE Forward 50(49.5) | NFE Backward 56(48.9) | CNF Time 0.5000(0.5000)
# Iter 0219 | Time 0.4470(0.4179) | Loss -0.347093(-0.494089) | NFE Forward 50(49.5) | NFE Backward 56(49.4) | CNF Time 0.5000(0.5000)
# Iter 0220 | Time 0.4451(0.4198) | Loss -0.383575(-0.486353) | NFE Forward 50(49.6) | NFE Backward 56(49.9) | CNF Time 0.5000(0.5000)
# Iter 0221 | Time 0.4466(0.4216) | Loss -0.497099(-0.487105) | NFE Forward 50(49.6) | NFE Backward 56(50.3) | CNF Time 0.5000(0.5000)
# Iter 0222 | Time 0.4294(0.4222) | Loss -0.778911(-0.507531) | NFE Forward 50(49.6) | NFE Backward 50(50.3) | CNF Time 0.5000(0.5000)
# Iter 0223 | Time 0.3917(0.4201) | Loss -0.049143(-0.475444) | NFE Forward 50(49.6) | NFE Backward 44(49.9) | CNF Time 0.5000(0.5000)
# Iter 0224 | Time 0.4209(0.4201) | Loss -1.180014(-0.524764) | NFE Forward 50(49.7) | NFE Backward 50(49.9) | CNF Time 0.5000(0.5000)
# Iter 0225 | Time 0.5507(0.4293) | Loss -0.361693(-0.513349) | NFE Forward 50(49.7) | NFE Backward 44(49.5) | CNF Time 0.5000(0.5000)
# Iter 0226 | Time 0.4185(0.4285) | Loss -0.858818(-0.537532) | NFE Forward 50(49.7) | NFE Backward 50(49.5) | CNF Time 0.5000(0.5000)
# Iter 0227 | Time 0.4233(0.4281) | Loss -0.879969(-0.561503) | NFE Forward 50(49.7) | NFE Backward 50(49.5) | CNF Time 0.5000(0.5000)
# Iter 0228 | Time 0.3828(0.4250) | Loss -0.078895(-0.527720) | NFE Forward 50(49.8) | NFE Backward 44(49.1) | CNF Time 0.5000(0.5000)
# Iter 0229 | Time 0.4171(0.4244) | Loss -1.028739(-0.562791) | NFE Forward 50(49.8) | NFE Backward 50(49.2) | CNF Time 0.5000(0.5000)
# Iter 0230 | Time 0.4195(0.4241) | Loss -0.019284(-0.524746) | NFE Forward 50(49.8) | NFE Backward 50(49.3) | CNF Time 0.5000(0.5000)
# Iter 0231 | Time 0.4318(0.4246) | Loss -0.637613(-0.532647) | NFE Forward 50(49.8) | NFE Backward 50(49.3) | CNF Time 0.5000(0.5000)
# Iter 0232 | Time 0.4463(0.4261) | Loss -0.347853(-0.519711) | NFE Forward 50(49.8) | NFE Backward 56(49.8) | CNF Time 0.5000(0.5000)
# Iter 0233 | Time 0.3870(0.4234) | Loss -0.658784(-0.529446) | NFE Forward 50(49.8) | NFE Backward 44(49.4) | CNF Time 0.5000(0.5000)
# Iter 0234 | Time 0.4462(0.4250) | Loss -0.215406(-0.507463) | NFE Forward 50(49.8) | NFE Backward 56(49.8) | CNF Time 0.5000(0.5000)
# Iter 0235 | Time 0.4461(0.4265) | Loss -0.016048(-0.473064) | NFE Forward 50(49.9) | NFE Backward 56(50.3) | CNF Time 0.5000(0.5000)
# Iter 0236 | Time 0.4100(0.4253) | Loss -0.424916(-0.469694) | NFE Forward 50(49.9) | NFE Backward 50(50.2) | CNF Time 0.5000(0.5000)
# Iter 0237 | Time 0.4181(0.4248) | Loss -0.799114(-0.492753) | NFE Forward 50(49.9) | NFE Backward 50(50.2) | CNF Time 0.5000(0.5000)
# Iter 0238 | Time 0.3873(0.4222) | Loss -1.158865(-0.539381) | NFE Forward 44(49.5) | NFE Backward 44(49.8) | CNF Time 0.5000(0.5000)
# Iter 0239 | Time 0.4475(0.4240) | Loss -0.334810(-0.525061) | NFE Forward 50(49.5) | NFE Backward 56(50.2) | CNF Time 0.5000(0.5000)
# Iter 0240 | Time 0.4448(0.4254) | Loss -0.325946(-0.511123) | NFE Forward 50(49.5) | NFE Backward 56(50.6) | CNF Time 0.5000(0.5000)
# Iter 0241 | Time 0.4178(0.4249) | Loss -0.133832(-0.484713) | NFE Forward 50(49.6) | NFE Backward 50(50.6) | CNF Time 0.5000(0.5000)
# Iter 0242 | Time 0.4162(0.4243) | Loss -0.637093(-0.495379) | NFE Forward 50(49.6) | NFE Backward 50(50.5) | CNF Time 0.5000(0.5000)
# Iter 0243 | Time 0.4378(0.4252) | Loss -0.029242(-0.462750) | NFE Forward 50(49.6) | NFE Backward 56(50.9) | CNF Time 0.5000(0.5000)
# Iter 0244 | Time 0.4456(0.4266) | Loss -0.409597(-0.459029) | NFE Forward 50(49.7) | NFE Backward 56(51.3) | CNF Time 0.5000(0.5000)
# Iter 0245 | Time 0.4210(0.4262) | Loss -0.934662(-0.492323) | NFE Forward 50(49.7) | NFE Backward 50(51.2) | CNF Time 0.5000(0.5000)
# Iter 0246 | Time 0.4173(0.4256) | Loss -0.755955(-0.510778) | NFE Forward 50(49.7) | NFE Backward 50(51.1) | CNF Time 0.5000(0.5000)
# Iter 0247 | Time 0.4192(0.4252) | Loss -0.855509(-0.534909) | NFE Forward 50(49.7) | NFE Backward 50(51.0) | CNF Time 0.5000(0.5000)
# Iter 0248 | Time 0.4203(0.4248) | Loss -0.563919(-0.536939) | NFE Forward 50(49.7) | NFE Backward 50(51.0) | CNF Time 0.5000(0.5000)
# Iter 0249 | Time 0.4185(0.4244) | Loss -0.970996(-0.567323) | NFE Forward 50(49.8) | NFE Backward 50(50.9) | CNF Time 0.5000(0.5000)
# Iter 0250 | Time 0.4193(0.4240) | Loss -0.729802(-0.578697) | NFE Forward 50(49.8) | NFE Backward 50(50.8) | CNF Time 0.5000(0.5000)
# Iter 0251 | Time 0.4164(0.4235) | Loss -0.742694(-0.590177) | NFE Forward 50(49.8) | NFE Backward 50(50.8) | CNF Time 0.5000(0.5000)
# Iter 0252 | Time 0.4174(0.4231) | Loss -0.649523(-0.594331) | NFE Forward 50(49.8) | NFE Backward 50(50.7) | CNF Time 0.5000(0.5000)
# Iter 0253 | Time 0.4513(0.4250) | Loss -0.406054(-0.581152) | NFE Forward 50(49.8) | NFE Backward 56(51.1) | CNF Time 0.5000(0.5000)
# Iter 0254 | Time 0.4206(0.4247) | Loss -0.567021(-0.580163) | NFE Forward 50(49.8) | NFE Backward 50(51.0) | CNF Time 0.5000(0.5000)
# Iter 0255 | Time 0.4491(0.4264) | Loss -0.586812(-0.580628) | NFE Forward 50(49.8) | NFE Backward 56(51.4) | CNF Time 0.5000(0.5000)
# Iter 0256 | Time 0.4409(0.4274) | Loss -0.474714(-0.573214) | NFE Forward 50(49.9) | NFE Backward 56(51.7) | CNF Time 0.5000(0.5000)
# Iter 0257 | Time 0.4505(0.4291) | Loss -0.079049(-0.538622) | NFE Forward 50(49.9) | NFE Backward 56(52.0) | CNF Time 0.5000(0.5000)
# Iter 0258 | Time 0.4185(0.4283) | Loss -1.010883(-0.571681) | NFE Forward 50(49.9) | NFE Backward 50(51.8) | CNF Time 0.5000(0.5000)
# Iter 0259 | Time 0.4130(0.4272) | Loss -0.487694(-0.565802) | NFE Forward 50(49.9) | NFE Backward 50(51.7) | CNF Time 0.5000(0.5000)
# Iter 0260 | Time 0.4501(0.4288) | Loss -0.302179(-0.547348) | NFE Forward 50(49.9) | NFE Backward 56(52.0) | CNF Time 0.5000(0.5000)
# Iter 0261 | Time 0.4224(0.4284) | Loss -1.115484(-0.587118) | NFE Forward 50(49.9) | NFE Backward 50(51.9) | CNF Time 0.5000(0.5000)
# Iter 0262 | Time 0.4187(0.4277) | Loss -0.060702(-0.550268) | NFE Forward 50(49.9) | NFE Backward 50(51.7) | CNF Time 0.5000(0.5000)
# Iter 0263 | Time 0.4478(0.4291) | Loss -0.483871(-0.545621) | NFE Forward 50(49.9) | NFE Backward 56(52.0) | CNF Time 0.5000(0.5000)
# Iter 0264 | Time 0.4187(0.4284) | Loss -0.572455(-0.547499) | NFE Forward 50(49.9) | NFE Backward 50(51.9) | CNF Time 0.5000(0.5000)
# Iter 0265 | Time 0.4495(0.4299) | Loss -0.597181(-0.550977) | NFE Forward 50(49.9) | NFE Backward 56(52.2) | CNF Time 0.5000(0.5000)
# Iter 0266 | Time 0.4433(0.4308) | Loss -0.103865(-0.519679) | NFE Forward 50(49.9) | NFE Backward 56(52.5) | CNF Time 0.5000(0.5000)
# Iter 0267 | Time 0.4216(0.4302) | Loss -0.886596(-0.545363) | NFE Forward 50(49.9) | NFE Backward 50(52.3) | CNF Time 0.5000(0.5000)
# Iter 0268 | Time 0.4231(0.4297) | Loss -0.868249(-0.567965) | NFE Forward 50(49.9) | NFE Backward 50(52.1) | CNF Time 0.5000(0.5000)
# Iter 0269 | Time 0.4237(0.4293) | Loss -1.021655(-0.599723) | NFE Forward 50(49.9) | NFE Backward 50(52.0) | CNF Time 0.5000(0.5000)
# Iter 0270 | Time 0.4198(0.4286) | Loss -0.635749(-0.602245) | NFE Forward 50(49.9) | NFE Backward 50(51.8) | CNF Time 0.5000(0.5000)
# Iter 0271 | Time 0.4223(0.4282) | Loss -0.898684(-0.622996) | NFE Forward 50(50.0) | NFE Backward 50(51.7) | CNF Time 0.5000(0.5000)
# Iter 0272 | Time 0.6098(0.4409) | Loss -0.888742(-0.641598) | NFE Forward 50(50.0) | NFE Backward 50(51.6) | CNF Time 0.5000(0.5000)
# Iter 0273 | Time 0.4103(0.4387) | Loss 0.257169(-0.578684) | NFE Forward 50(50.0) | NFE Backward 50(51.5) | CNF Time 0.5000(0.5000)
# Iter 0274 | Time 0.3905(0.4354) | Loss -0.286730(-0.558248) | NFE Forward 50(50.0) | NFE Backward 44(51.0) | CNF Time 0.5000(0.5000)
# Iter 0275 | Time 0.4219(0.4344) | Loss -0.916411(-0.583319) | NFE Forward 50(50.0) | NFE Backward 50(50.9) | CNF Time 0.5000(0.5000)
# Iter 0276 | Time 0.4219(0.4335) | Loss -0.753222(-0.595212) | NFE Forward 50(50.0) | NFE Backward 50(50.8) | CNF Time 0.5000(0.5000)
# Iter 0277 | Time 0.4125(0.4321) | Loss 0.101239(-0.546461) | NFE Forward 50(50.0) | NFE Backward 50(50.8) | CNF Time 0.5000(0.5000)
# Iter 0278 | Time 0.4503(0.4333) | Loss -0.071589(-0.513220) | NFE Forward 50(50.0) | NFE Backward 56(51.1) | CNF Time 0.5000(0.5000)
# Iter 0279 | Time 0.4180(0.4323) | Loss -0.885683(-0.539292) | NFE Forward 50(50.0) | NFE Backward 50(51.1) | CNF Time 0.5000(0.5000)
# Iter 0280 | Time 0.4186(0.4313) | Loss -1.027708(-0.573481) | NFE Forward 50(50.0) | NFE Backward 50(51.0) | CNF Time 0.5000(0.5000)
# Iter 0281 | Time 0.4423(0.4321) | Loss -0.546310(-0.571579) | NFE Forward 50(50.0) | NFE Backward 56(51.3) | CNF Time 0.5000(0.5000)
# Iter 0282 | Time 0.4201(0.4312) | Loss -0.883049(-0.593382) | NFE Forward 50(50.0) | NFE Backward 50(51.2) | CNF Time 0.5000(0.5000)
# Iter 0283 | Time 0.3897(0.4283) | Loss 0.022821(-0.550248) | NFE Forward 50(50.0) | NFE Backward 44(50.7) | CNF Time 0.5000(0.5000)
# Iter 0284 | Time 0.3925(0.4258) | Loss -0.952887(-0.578433) | NFE Forward 50(50.0) | NFE Backward 44(50.3) | CNF Time 0.5000(0.5000)
# Iter 0285 | Time 0.4210(0.4255) | Loss -1.180780(-0.620597) | NFE Forward 50(50.0) | NFE Backward 50(50.2) | CNF Time 0.5000(0.5000)
# Iter 0286 | Time 0.4203(0.4251) | Loss -0.669131(-0.623994) | NFE Forward 50(50.0) | NFE Backward 50(50.2) | CNF Time 0.5000(0.5000)
# Iter 0287 | Time 0.4475(0.4267) | Loss -0.829791(-0.638400) | NFE Forward 50(50.0) | NFE Backward 56(50.6) | CNF Time 0.5000(0.5000)
# Iter 0288 | Time 0.3887(0.4240) | Loss -1.216216(-0.678847) | NFE Forward 44(49.6) | NFE Backward 44(50.2) | CNF Time 0.5000(0.5000)
# Iter 0289 | Time 0.3895(0.4216) | Loss -1.175139(-0.713588) | NFE Forward 50(49.6) | NFE Backward 44(49.7) | CNF Time 0.5000(0.5000)
# Iter 0290 | Time 0.4215(0.4216) | Loss -0.848143(-0.723007) | NFE Forward 50(49.6) | NFE Backward 50(49.8) | CNF Time 0.5000(0.5000)
# Iter 0291 | Time 0.3928(0.4196) | Loss 0.227027(-0.656504) | NFE Forward 50(49.7) | NFE Backward 44(49.3) | CNF Time 0.5000(0.5000)
# Iter 0292 | Time 0.4418(0.4211) | Loss -0.051870(-0.614180) | NFE Forward 50(49.7) | NFE Backward 56(49.8) | CNF Time 0.5000(0.5000)
# Iter 0293 | Time 0.4181(0.4209) | Loss -0.426236(-0.601024) | NFE Forward 50(49.7) | NFE Backward 50(49.8) | CNF Time 0.5000(0.5000)
# Iter 0294 | Time 0.4186(0.4208) | Loss -1.008833(-0.629570) | NFE Forward 50(49.7) | NFE Backward 50(49.8) | CNF Time 0.5000(0.5000)
# Iter 0295 | Time 0.3783(0.4178) | Loss -1.268107(-0.674268) | NFE Forward 44(49.3) | NFE Backward 44(49.4) | CNF Time 0.5000(0.5000)
# Iter 0296 | Time 0.4150(0.4176) | Loss -1.077051(-0.702463) | NFE Forward 50(49.4) | NFE Backward 50(49.5) | CNF Time 0.5000(0.5000)
# Iter 0297 | Time 0.4470(0.4197) | Loss -0.223535(-0.668938) | NFE Forward 50(49.4) | NFE Backward 56(49.9) | CNF Time 0.5000(0.5000)
# Iter 0298 | Time 0.4475(0.4216) | Loss -0.745725(-0.674313) | NFE Forward 50(49.5) | NFE Backward 56(50.4) | CNF Time 0.5000(0.5000)
# Iter 0299 | Time 0.4192(0.4214) | Loss -0.562503(-0.666486) | NFE Forward 50(49.5) | NFE Backward 50(50.3) | CNF Time 0.5000(0.5000)
# Iter 0300 | Time 0.4491(0.4234) | Loss -0.056189(-0.623765) | NFE Forward 50(49.5) | NFE Backward 56(50.7) | CNF Time 0.5000(0.5000)
# Iter 0301 | Time 0.4191(0.4231) | Loss -0.496880(-0.614883) | NFE Forward 50(49.6) | NFE Backward 44(50.3) | CNF Time 0.5000(0.5000)
# Iter 0302 | Time 0.4792(0.4270) | Loss 0.025354(-0.570067) | NFE Forward 50(49.6) | NFE Backward 56(50.7) | CNF Time 0.5000(0.5000)
# Iter 0303 | Time 0.4638(0.4296) | Loss -1.107082(-0.607658) | NFE Forward 50(49.6) | NFE Backward 50(50.6) | CNF Time 0.5000(0.5000)
# Iter 0304 | Time 0.4367(0.4301) | Loss -0.941555(-0.631031) | NFE Forward 50(49.6) | NFE Backward 50(50.6) | CNF Time 0.5000(0.5000)
# Iter 0305 | Time 0.4165(0.4291) | Loss -1.117978(-0.665117) | NFE Forward 50(49.7) | NFE Backward 50(50.5) | CNF Time 0.5000(0.5000)
# Iter 0306 | Time 0.4091(0.4277) | Loss -0.577536(-0.658986) | NFE Forward 50(49.7) | NFE Backward 50(50.5) | CNF Time 0.5000(0.5000)
# Iter 0307 | Time 0.4181(0.4270) | Loss -0.033074(-0.615172) | NFE Forward 50(49.7) | NFE Backward 50(50.5) | CNF Time 0.5000(0.5000)
# Iter 0308 | Time 0.4193(0.4265) | Loss -1.266108(-0.660738) | NFE Forward 50(49.7) | NFE Backward 50(50.4) | CNF Time 0.5000(0.5000)
# Iter 0309 | Time 0.4492(0.4281) | Loss -0.576959(-0.654873) | NFE Forward 50(49.8) | NFE Backward 56(50.8) | CNF Time 0.5000(0.5000)
# Iter 0310 | Time 0.4502(0.4296) | Loss -0.440651(-0.639878) | NFE Forward 50(49.8) | NFE Backward 56(51.2) | CNF Time 0.5000(0.5000)
# Iter 0311 | Time 0.4204(0.4290) | Loss -0.435822(-0.625594) | NFE Forward 50(49.8) | NFE Backward 50(51.1) | CNF Time 0.5000(0.5000)
# Iter 0312 | Time 0.3926(0.4264) | Loss -0.237227(-0.598408) | NFE Forward 50(49.8) | NFE Backward 44(50.6) | CNF Time 0.5000(0.5000)
# Iter 0313 | Time 0.4221(0.4261) | Loss -0.905828(-0.619928) | NFE Forward 50(49.8) | NFE Backward 50(50.6) | CNF Time 0.5000(0.5000)
# Iter 0314 | Time 0.4226(0.4259) | Loss 0.113878(-0.568561) | NFE Forward 50(49.8) | NFE Backward 50(50.5) | CNF Time 0.5000(0.5000)
# Iter 0315 | Time 0.4286(0.4261) | Loss -0.848874(-0.588183) | NFE Forward 50(49.8) | NFE Backward 50(50.5) | CNF Time 0.5000(0.5000)
# Iter 0316 | Time 0.4221(0.4258) | Loss -0.369313(-0.572862) | NFE Forward 50(49.9) | NFE Backward 50(50.4) | CNF Time 0.5000(0.5000)
# Iter 0317 | Time 0.4124(0.4249) | Loss -0.663863(-0.579232) | NFE Forward 50(49.9) | NFE Backward 50(50.4) | CNF Time 0.5000(0.5000)
# Iter 0318 | Time 0.3924(0.4226) | Loss -0.193769(-0.552250) | NFE Forward 50(49.9) | NFE Backward 44(50.0) | CNF Time 0.5000(0.5000)
# Iter 0319 | Time 0.4136(0.4220) | Loss -0.372158(-0.539643) | NFE Forward 50(49.9) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 0320 | Time 0.4224(0.4220) | Loss -0.329351(-0.524923) | NFE Forward 50(49.9) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 0321 | Time 0.4127(0.4213) | Loss -0.272925(-0.507283) | NFE Forward 50(49.9) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 0322 | Time 0.4130(0.4208) | Loss -0.660475(-0.518007) | NFE Forward 50(49.9) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 0323 | Time 0.4180(0.4206) | Loss -0.915989(-0.545865) | NFE Forward 50(49.9) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 0324 | Time 0.4488(0.4225) | Loss -0.460832(-0.539913) | NFE Forward 50(49.9) | NFE Backward 56(50.4) | CNF Time 0.5000(0.5000)
# Iter 0325 | Time 0.4153(0.4220) | Loss -1.320870(-0.594580) | NFE Forward 50(49.9) | NFE Backward 44(50.0) | CNF Time 0.5000(0.5000)
# Iter 0326 | Time 0.4160(0.4216) | Loss -1.053737(-0.626721) | NFE Forward 50(49.9) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 0327 | Time 0.7260(0.4429) | Loss -0.792607(-0.638333) | NFE Forward 50(49.9) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 0328 | Time 0.4204(0.4413) | Loss -1.155860(-0.674560) | NFE Forward 50(49.9) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 0329 | Time 0.4344(0.4409) | Loss -0.816152(-0.684471) | NFE Forward 50(49.9) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 0330 | Time 0.4185(0.4393) | Loss -0.629871(-0.680649) | NFE Forward 50(49.9) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 0331 | Time 0.4176(0.4378) | Loss -0.749040(-0.685437) | NFE Forward 50(50.0) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 0332 | Time 0.4189(0.4365) | Loss -0.665376(-0.684032) | NFE Forward 50(50.0) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 0333 | Time 0.4193(0.4352) | Loss -0.567669(-0.675887) | NFE Forward 50(50.0) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 0334 | Time 0.4484(0.4362) | Loss -0.305618(-0.649968) | NFE Forward 50(50.0) | NFE Backward 56(50.4) | CNF Time 0.5000(0.5000)
# Iter 0335 | Time 0.4465(0.4369) | Loss -0.395478(-0.632154) | NFE Forward 50(50.0) | NFE Backward 56(50.8) | CNF Time 0.5000(0.5000)
# Iter 0336 | Time 0.4179(0.4356) | Loss -0.843974(-0.646981) | NFE Forward 50(50.0) | NFE Backward 50(50.7) | CNF Time 0.5000(0.5000)
# Iter 0337 | Time 0.4202(0.4345) | Loss -0.938693(-0.667401) | NFE Forward 50(50.0) | NFE Backward 50(50.7) | CNF Time 0.5000(0.5000)
# Iter 0338 | Time 0.4472(0.4354) | Loss -0.362208(-0.646038) | NFE Forward 50(50.0) | NFE Backward 50(50.6) | CNF Time 0.5000(0.5000)
# Iter 0339 | Time 0.4173(0.4341) | Loss -0.885585(-0.662806) | NFE Forward 50(50.0) | NFE Backward 50(50.6) | CNF Time 0.5000(0.5000)
# Iter 0340 | Time 0.4171(0.4329) | Loss -0.985339(-0.685383) | NFE Forward 50(50.0) | NFE Backward 50(50.5) | CNF Time 0.5000(0.5000)
# Iter 0341 | Time 0.4172(0.4318) | Loss -1.052428(-0.711076) | NFE Forward 50(50.0) | NFE Backward 50(50.5) | CNF Time 0.5000(0.5000)
# Iter 0342 | Time 0.4197(0.4310) | Loss -0.916221(-0.725436) | NFE Forward 50(50.0) | NFE Backward 50(50.5) | CNF Time 0.5000(0.5000)
# Iter 0343 | Time 0.4180(0.4301) | Loss -1.153422(-0.755395) | NFE Forward 50(50.0) | NFE Backward 50(50.4) | CNF Time 0.5000(0.5000)
# Iter 0344 | Time 0.4456(0.4312) | Loss -0.781665(-0.757234) | NFE Forward 50(50.0) | NFE Backward 56(50.8) | CNF Time 0.5000(0.5000)
# Iter 0345 | Time 0.4373(0.4316) | Loss -0.338127(-0.727897) | NFE Forward 50(50.0) | NFE Backward 56(51.2) | CNF Time 0.5000(0.5000)
# Iter 0346 | Time 0.4169(0.4306) | Loss -1.039603(-0.749716) | NFE Forward 50(50.0) | NFE Backward 50(51.1) | CNF Time 0.5000(0.5000)
# Iter 0347 | Time 0.4124(0.4293) | Loss -0.188373(-0.710422) | NFE Forward 50(50.0) | NFE Backward 50(51.0) | CNF Time 0.5000(0.5000)
# Iter 0348 | Time 0.4096(0.4279) | Loss 0.430541(-0.630555) | NFE Forward 50(50.0) | NFE Backward 50(51.0) | CNF Time 0.5000(0.5000)
# Iter 0349 | Time 0.4160(0.4271) | Loss -0.776636(-0.640780) | NFE Forward 50(50.0) | NFE Backward 50(50.9) | CNF Time 0.5000(0.5000)
# Iter 0350 | Time 0.4195(0.4265) | Loss -0.154659(-0.606752) | NFE Forward 50(50.0) | NFE Backward 50(50.8) | CNF Time 0.5000(0.5000)
# Iter 0351 | Time 0.4188(0.4260) | Loss -0.859619(-0.624453) | NFE Forward 50(50.0) | NFE Backward 50(50.8) | CNF Time 0.5000(0.5000)
# Iter 0352 | Time 0.3901(0.4235) | Loss -0.974949(-0.648987) | NFE Forward 50(50.0) | NFE Backward 44(50.3) | CNF Time 0.5000(0.5000)
# Iter 0353 | Time 0.4496(0.4253) | Loss -1.097828(-0.680406) | NFE Forward 50(50.0) | NFE Backward 50(50.3) | CNF Time 0.5000(0.5000)
# Iter 0354 | Time 0.4133(0.4245) | Loss -0.505842(-0.668187) | NFE Forward 50(50.0) | NFE Backward 50(50.3) | CNF Time 0.5000(0.5000)
# Iter 0355 | Time 0.4227(0.4244) | Loss -0.897932(-0.684269) | NFE Forward 50(50.0) | NFE Backward 50(50.2) | CNF Time 0.5000(0.5000)
# Iter 0356 | Time 0.4636(0.4271) | Loss -0.325708(-0.659170) | NFE Forward 50(50.0) | NFE Backward 56(50.6) | CNF Time 0.5000(0.5000)
# Iter 0357 | Time 0.3858(0.4242) | Loss -0.226129(-0.628857) | NFE Forward 50(50.0) | NFE Backward 44(50.2) | CNF Time 0.5000(0.5000)
# Iter 0358 | Time 0.4164(0.4237) | Loss -1.103187(-0.662060) | NFE Forward 50(50.0) | NFE Backward 50(50.2) | CNF Time 0.5000(0.5000)
# Iter 0359 | Time 0.4171(0.4232) | Loss -1.279933(-0.705311) | NFE Forward 50(50.0) | NFE Backward 50(50.2) | CNF Time 0.5000(0.5000)
# Iter 0360 | Time 0.4354(0.4241) | Loss -0.325579(-0.678730) | NFE Forward 50(50.0) | NFE Backward 56(50.6) | CNF Time 0.5000(0.5000)
# Iter 0361 | Time 0.4077(0.4229) | Loss -1.316941(-0.723405) | NFE Forward 44(49.6) | NFE Backward 50(50.5) | CNF Time 0.5000(0.5000)
# Iter 0362 | Time 0.4384(0.4240) | Loss -0.313700(-0.694725) | NFE Forward 50(49.6) | NFE Backward 56(50.9) | CNF Time 0.5000(0.5000)
# Iter 0363 | Time 0.4474(0.4256) | Loss -0.675951(-0.693411) | NFE Forward 50(49.6) | NFE Backward 56(51.3) | CNF Time 0.5000(0.5000)
# ...
# Iter 1331 | Time 0.3921(0.4114) | Loss -0.762412(-0.773689) | NFE Forward 50(48.7) | NFE Backward 44(48.9) | CNF Time 0.5000(0.5000)
# Iter 1332 | Time 0.4210(0.4121) | Loss 0.088900(-0.713307) | NFE Forward 50(48.7) | NFE Backward 50(49.0) | CNF Time 0.5000(0.5000)
# Iter 1333 | Time 0.4215(0.4127) | Loss -0.832067(-0.721621) | NFE Forward 50(48.8) | NFE Backward 50(49.1) | CNF Time 0.5000(0.5000)
# Iter 1334 | Time 0.4201(0.4133) | Loss -0.967545(-0.738835) | NFE Forward 50(48.9) | NFE Backward 50(49.1) | CNF Time 0.5000(0.5000)
# Iter 1335 | Time 0.4244(0.4140) | Loss -0.124739(-0.695849) | NFE Forward 50(49.0) | NFE Backward 50(49.2) | CNF Time 0.5000(0.5000)
# Iter 1336 | Time 0.4224(0.4146) | Loss -0.586609(-0.688202) | NFE Forward 50(49.1) | NFE Backward 50(49.2) | CNF Time 0.5000(0.5000)
# Iter 1337 | Time 0.4164(0.4148) | Loss -0.366380(-0.665674) | NFE Forward 50(49.1) | NFE Backward 50(49.3) | CNF Time 0.5000(0.5000)
# Iter 1338 | Time 0.4261(0.4155) | Loss -0.532270(-0.656336) | NFE Forward 50(49.2) | NFE Backward 50(49.3) | CNF Time 0.5000(0.5000)
# Iter 1339 | Time 0.4147(0.4155) | Loss -0.036140(-0.612922) | NFE Forward 50(49.2) | NFE Backward 50(49.4) | CNF Time 0.5000(0.5000)
# Iter 1340 | Time 0.4527(0.4181) | Loss -0.101730(-0.577139) | NFE Forward 50(49.3) | NFE Backward 56(49.8) | CNF Time 0.5000(0.5000)
# Iter 1341 | Time 0.4221(0.4184) | Loss -0.700629(-0.585783) | NFE Forward 50(49.3) | NFE Backward 50(49.9) | CNF Time 0.5000(0.5000)
# Iter 1342 | Time 0.3936(0.4166) | Loss -0.928262(-0.609757) | NFE Forward 50(49.4) | NFE Backward 44(49.4) | CNF Time 0.5000(0.5000)
# Iter 1343 | Time 0.4251(0.4172) | Loss -0.658621(-0.613177) | NFE Forward 50(49.4) | NFE Backward 50(49.5) | CNF Time 0.5000(0.5000)
# Iter 1344 | Time 0.4534(0.4198) | Loss -0.353513(-0.595001) | NFE Forward 50(49.5) | NFE Backward 56(49.9) | CNF Time 0.5000(0.5000)
# Iter 1345 | Time 0.3965(0.4181) | Loss -1.433881(-0.653722) | NFE Forward 50(49.5) | NFE Backward 44(49.5) | CNF Time 0.5000(0.5000)
# Iter 1346 | Time 0.4269(0.4187) | Loss -0.826225(-0.665797) | NFE Forward 50(49.5) | NFE Backward 50(49.6) | CNF Time 0.5000(0.5000)
# Iter 1347 | Time 0.4427(0.4204) | Loss 0.105311(-0.611820) | NFE Forward 50(49.6) | NFE Backward 56(50.0) | CNF Time 0.5000(0.5000)
# Iter 1348 | Time 0.4227(0.4206) | Loss -0.751277(-0.621582) | NFE Forward 50(49.6) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 1349 | Time 0.3870(0.4182) | Loss -0.692133(-0.626521) | NFE Forward 50(49.6) | NFE Backward 44(49.6) | CNF Time 0.5000(0.5000)
# Iter 1350 | Time 0.4245(0.4187) | Loss -0.064639(-0.587189) | NFE Forward 50(49.7) | NFE Backward 50(49.6) | CNF Time 0.5000(0.5000)
# Iter 1351 | Time 0.4100(0.4181) | Loss -0.866797(-0.606761) | NFE Forward 44(49.3) | NFE Backward 50(49.6) | CNF Time 0.5000(0.5000)
# Iter 1352 | Time 0.4266(0.4187) | Loss -0.215600(-0.579380) | NFE Forward 50(49.3) | NFE Backward 50(49.7) | CNF Time 0.5000(0.5000)
# Iter 1353 | Time 0.4597(0.4215) | Loss -0.400995(-0.566893) | NFE Forward 50(49.4) | NFE Backward 56(50.1) | CNF Time 0.5000(0.5000)
# Iter 1354 | Time 0.3974(0.4198) | Loss -0.531221(-0.564396) | NFE Forward 50(49.4) | NFE Backward 44(49.7) | CNF Time 0.5000(0.5000)
# Iter 1355 | Time 0.3966(0.4182) | Loss -0.849745(-0.584371) | NFE Forward 50(49.4) | NFE Backward 44(49.3) | CNF Time 0.5000(0.5000)
# Iter 1356 | Time 0.4287(0.4189) | Loss -0.668196(-0.590238) | NFE Forward 50(49.5) | NFE Backward 50(49.3) | CNF Time 0.5000(0.5000)
# Iter 1357 | Time 0.3948(0.4173) | Loss -1.125048(-0.627675) | NFE Forward 50(49.5) | NFE Backward 44(49.0) | CNF Time 0.5000(0.5000)
# Iter 1358 | Time 0.4160(0.4172) | Loss 0.224393(-0.568030) | NFE Forward 50(49.6) | NFE Backward 50(49.0) | CNF Time 0.5000(0.5000)
# Iter 1359 | Time 0.4264(0.4178) | Loss -0.921303(-0.592759) | NFE Forward 50(49.6) | NFE Backward 50(49.1) | CNF Time 0.5000(0.5000)
# Iter 1360 | Time 0.4160(0.4177) | Loss -0.268741(-0.570078) | NFE Forward 50(49.6) | NFE Backward 50(49.2) | CNF Time 0.5000(0.5000)
# Iter 1361 | Time 0.4164(0.4176) | Loss -0.526874(-0.567054) | NFE Forward 50(49.6) | NFE Backward 50(49.2) | CNF Time 0.5000(0.5000)
# Iter 1362 | Time 0.4243(0.4181) | Loss -0.298160(-0.548231) | NFE Forward 50(49.7) | NFE Backward 50(49.3) | CNF Time 0.5000(0.5000)
# Iter 1363 | Time 0.3912(0.4162) | Loss -1.362067(-0.605200) | NFE Forward 50(49.7) | NFE Backward 44(48.9) | CNF Time 0.5000(0.5000)
# Iter 1364 | Time 0.4150(0.4161) | Loss -0.549659(-0.601312) | NFE Forward 50(49.7) | NFE Backward 50(49.0) | CNF Time 0.5000(0.5000)
# Iter 1365 | Time 0.4159(0.4161) | Loss -0.394880(-0.586862) | NFE Forward 50(49.7) | NFE Backward 50(49.1) | CNF Time 0.5000(0.5000)
# Iter 1366 | Time 0.4226(0.4165) | Loss -0.783909(-0.600655) | NFE Forward 50(49.8) | NFE Backward 50(49.1) | CNF Time 0.5000(0.5000)
# Iter 1367 | Time 0.4244(0.4171) | Loss -0.870622(-0.619553) | NFE Forward 50(49.8) | NFE Backward 50(49.2) | CNF Time 0.5000(0.5000)
# Iter 1368 | Time 0.4254(0.4177) | Loss -0.569967(-0.616082) | NFE Forward 50(49.8) | NFE Backward 50(49.2) | CNF Time 0.5000(0.5000)
# Iter 1369 | Time 0.4220(0.4180) | Loss -0.435747(-0.603458) | NFE Forward 50(49.8) | NFE Backward 50(49.3) | CNF Time 0.5000(0.5000)
# Iter 1370 | Time 0.4216(0.4182) | Loss -0.706295(-0.610657) | NFE Forward 50(49.8) | NFE Backward 50(49.3) | CNF Time 0.5000(0.5000)
# Iter 1371 | Time 0.3938(0.4165) | Loss -0.923919(-0.632585) | NFE Forward 50(49.8) | NFE Backward 44(49.0) | CNF Time 0.5000(0.5000)
# Iter 1372 | Time 0.4239(0.4170) | Loss -0.726046(-0.639127) | NFE Forward 50(49.8) | NFE Backward 50(49.0) | CNF Time 0.5000(0.5000)
# Iter 1373 | Time 0.4158(0.4170) | Loss -0.196029(-0.608110) | NFE Forward 50(49.9) | NFE Backward 50(49.1) | CNF Time 0.5000(0.5000)
# Iter 1374 | Time 0.4244(0.4175) | Loss -0.784165(-0.620434) | NFE Forward 50(49.9) | NFE Backward 50(49.2) | CNF Time 0.5000(0.5000)
# Iter 1375 | Time 0.4232(0.4179) | Loss -1.323673(-0.669661) | NFE Forward 50(49.9) | NFE Backward 50(49.2) | CNF Time 0.5000(0.5000)
# Iter 1376 | Time 0.4510(0.4202) | Loss -0.546838(-0.661063) | NFE Forward 50(49.9) | NFE Backward 56(49.7) | CNF Time 0.5000(0.5000)
# Iter 1377 | Time 0.4137(0.4197) | Loss -0.736860(-0.666369) | NFE Forward 50(49.9) | NFE Backward 50(49.7) | CNF Time 0.5000(0.5000)
# Iter 1378 | Time 0.4155(0.4194) | Loss -0.091482(-0.626127) | NFE Forward 50(49.9) | NFE Backward 50(49.7) | CNF Time 0.5000(0.5000)
# Iter 1379 | Time 0.4233(0.4197) | Loss -0.670640(-0.629243) | NFE Forward 50(49.9) | NFE Backward 50(49.8) | CNF Time 0.5000(0.5000)
# Iter 1380 | Time 0.3347(0.4138) | Loss -1.013177(-0.656118) | NFE Forward 38(49.1) | NFE Backward 38(48.9) | CNF Time 0.5000(0.5000)
# Iter 1381 | Time 0.4239(0.4145) | Loss -0.921426(-0.674690) | NFE Forward 50(49.1) | NFE Backward 50(49.0) | CNF Time 0.5000(0.5000)
# Iter 1382 | Time 0.4236(0.4151) | Loss -0.594155(-0.669053) | NFE Forward 50(49.2) | NFE Backward 50(49.1) | CNF Time 0.5000(0.5000)
# Iter 1383 | Time 0.3942(0.4136) | Loss -1.010423(-0.692948) | NFE Forward 50(49.3) | NFE Backward 44(48.7) | CNF Time 0.5000(0.5000)
# Iter 1384 | Time 0.4262(0.4145) | Loss -0.420846(-0.673901) | NFE Forward 50(49.3) | NFE Backward 50(48.8) | CNF Time 0.5000(0.5000)
# Iter 1385 | Time 0.4245(0.4152) | Loss -1.148527(-0.707125) | NFE Forward 50(49.4) | NFE Backward 50(48.9) | CNF Time 0.5000(0.5000)
# Iter 1386 | Time 0.4233(0.4158) | Loss -0.745846(-0.709836) | NFE Forward 50(49.4) | NFE Backward 50(49.0) | CNF Time 0.5000(0.5000)
# Iter 1387 | Time 0.4421(0.4176) | Loss -0.215093(-0.675204) | NFE Forward 50(49.4) | NFE Backward 56(49.5) | CNF Time 0.5000(0.5000)
# Iter 1388 | Time 0.3936(0.4160) | Loss -1.051342(-0.701533) | NFE Forward 50(49.5) | NFE Backward 44(49.1) | CNF Time 0.5000(0.5000)
# Iter 1389 | Time 0.4543(0.4186) | Loss 0.097161(-0.645625) | NFE Forward 50(49.5) | NFE Backward 56(49.6) | CNF Time 0.5000(0.5000)
# Iter 1390 | Time 0.3926(0.4168) | Loss -1.162159(-0.681782) | NFE Forward 50(49.6) | NFE Backward 44(49.2) | CNF Time 0.5000(0.5000)
# Iter 1391 | Time 0.4220(0.4172) | Loss -0.915903(-0.698171) | NFE Forward 50(49.6) | NFE Backward 50(49.2) | CNF Time 0.5000(0.5000)
# Iter 1392 | Time 0.4215(0.4175) | Loss -0.597165(-0.691100) | NFE Forward 50(49.6) | NFE Backward 50(49.3) | CNF Time 0.5000(0.5000)
# Iter 1393 | Time 0.4518(0.4199) | Loss -0.470114(-0.675631) | NFE Forward 50(49.6) | NFE Backward 56(49.8) | CNF Time 0.5000(0.5000)
# Iter 1394 | Time 0.4231(0.4201) | Loss -0.516548(-0.664495) | NFE Forward 50(49.7) | NFE Backward 50(49.8) | CNF Time 0.5000(0.5000)
# Iter 1395 | Time 0.4539(0.4225) | Loss -0.328394(-0.640968) | NFE Forward 50(49.7) | NFE Backward 56(50.2) | CNF Time 0.5000(0.5000)
# Iter 1396 | Time 0.4215(0.4224) | Loss -0.783030(-0.650913) | NFE Forward 50(49.7) | NFE Backward 50(50.2) | CNF Time 0.5000(0.5000)
# Iter 1397 | Time 0.3921(0.4203) | Loss -0.937759(-0.670992) | NFE Forward 50(49.7) | NFE Backward 44(49.8) | CNF Time 0.5000(0.5000)
# Iter 1398 | Time 0.4240(0.4205) | Loss -0.901947(-0.687159) | NFE Forward 50(49.7) | NFE Backward 50(49.8) | CNF Time 0.5000(0.5000)
# Iter 1399 | Time 0.3928(0.4186) | Loss -0.863388(-0.699495) | NFE Forward 50(49.8) | NFE Backward 44(49.4) | CNF Time 0.5000(0.5000)
# Iter 1400 | Time 0.4094(0.4180) | Loss -0.821852(-0.708060) | NFE Forward 44(49.4) | NFE Backward 50(49.4) | CNF Time 0.5000(0.5000)
# Iter 1401 | Time 0.4350(0.4192) | Loss -0.593638(-0.700050) | NFE Forward 50(49.4) | NFE Backward 50(49.5) | CNF Time 0.5000(0.5000)
# Iter 1402 | Time 0.4404(0.4206) | Loss -0.778752(-0.705559) | NFE Forward 50(49.4) | NFE Backward 50(49.5) | CNF Time 0.5000(0.5000)
# Iter 1403 | Time 0.3974(0.4190) | Loss -0.697103(-0.704967) | NFE Forward 50(49.5) | NFE Backward 44(49.1) | CNF Time 0.5000(0.5000)
# Iter 1404 | Time 0.4223(0.4192) | Loss -0.875747(-0.716922) | NFE Forward 50(49.5) | NFE Backward 50(49.2) | CNF Time 0.5000(0.5000)
# Iter 1405 | Time 0.4210(0.4194) | Loss -0.694697(-0.715366) | NFE Forward 50(49.6) | NFE Backward 50(49.2) | CNF Time 0.5000(0.5000)
# Iter 1406 | Time 0.4509(0.4216) | Loss -0.528612(-0.702293) | NFE Forward 50(49.6) | NFE Backward 56(49.7) | CNF Time 0.5000(0.5000)
# Iter 1407 | Time 0.4636(0.4245) | Loss 0.170620(-0.641190) | NFE Forward 50(49.6) | NFE Backward 56(50.1) | CNF Time 0.5000(0.5000)
# Iter 1408 | Time 0.3853(0.4218) | Loss -0.778391(-0.650794) | NFE Forward 50(49.6) | NFE Backward 44(49.7) | CNF Time 0.5000(0.5000)
# Iter 1409 | Time 0.4242(0.4219) | Loss -1.023596(-0.676890) | NFE Forward 50(49.7) | NFE Backward 50(49.7) | CNF Time 0.5000(0.5000)
# Iter 1410 | Time 0.4239(0.4221) | Loss -1.181579(-0.712218) | NFE Forward 50(49.7) | NFE Backward 50(49.8) | CNF Time 0.5000(0.5000)
# Iter 1411 | Time 0.4237(0.4222) | Loss -1.232955(-0.748670) | NFE Forward 50(49.7) | NFE Backward 50(49.8) | CNF Time 0.5000(0.5000)
# Iter 1412 | Time 0.3952(0.4203) | Loss -1.072574(-0.771343) | NFE Forward 50(49.7) | NFE Backward 44(49.4) | CNF Time 0.5000(0.5000)
# Iter 1413 | Time 0.4549(0.4227) | Loss -0.612462(-0.760221) | NFE Forward 50(49.8) | NFE Backward 56(49.8) | CNF Time 0.5000(0.5000)
# Iter 1414 | Time 0.4254(0.4229) | Loss -0.725891(-0.757818) | NFE Forward 50(49.8) | NFE Backward 50(49.8) | CNF Time 0.5000(0.5000)
# Iter 1415 | Time 0.4242(0.4230) | Loss -0.998251(-0.774648) | NFE Forward 50(49.8) | NFE Backward 50(49.9) | CNF Time 0.5000(0.5000)
# Iter 1416 | Time 0.4518(0.4250) | Loss -0.309125(-0.742062) | NFE Forward 50(49.8) | NFE Backward 56(50.3) | CNF Time 0.5000(0.5000)
# Iter 1417 | Time 0.3979(0.4231) | Loss -1.079084(-0.765653) | NFE Forward 38(49.0) | NFE Backward 50(50.3) | CNF Time 0.5000(0.5000)
# Iter 1418 | Time 0.4452(0.4247) | Loss 0.126003(-0.703237) | NFE Forward 50(49.0) | NFE Backward 56(50.7) | CNF Time 0.5000(0.5000)
# Iter 1419 | Time 0.4249(0.4247) | Loss -0.194399(-0.667619) | NFE Forward 50(49.1) | NFE Backward 50(50.6) | CNF Time 0.5000(0.5000)
# Iter 1420 | Time 0.4261(0.4248) | Loss -0.883149(-0.682706) | NFE Forward 50(49.2) | NFE Backward 50(50.6) | CNF Time 0.5000(0.5000)
# Iter 1421 | Time 0.4189(0.4244) | Loss -0.681959(-0.682654) | NFE Forward 50(49.2) | NFE Backward 50(50.5) | CNF Time 0.5000(0.5000)
# Iter 1422 | Time 0.3959(0.4224) | Loss -1.183040(-0.717681) | NFE Forward 50(49.3) | NFE Backward 44(50.1) | CNF Time 0.5000(0.5000)
# Iter 1423 | Time 0.4266(0.4227) | Loss -0.819096(-0.724780) | NFE Forward 50(49.3) | NFE Backward 50(50.1) | CNF Time 0.5000(0.5000)
# Iter 1424 | Time 0.4247(0.4228) | Loss -1.198310(-0.757927) | NFE Forward 50(49.4) | NFE Backward 50(50.1) | CNF Time 0.5000(0.5000)
# Iter 1425 | Time 0.4263(0.4231) | Loss -0.525821(-0.741679) | NFE Forward 50(49.4) | NFE Backward 50(50.1) | CNF Time 0.5000(0.5000)
# Iter 1426 | Time 0.4244(0.4232) | Loss -0.701292(-0.738852) | NFE Forward 50(49.5) | NFE Backward 50(50.1) | CNF Time 0.5000(0.5000)
# Iter 1427 | Time 0.4281(0.4235) | Loss -1.041944(-0.760069) | NFE Forward 50(49.5) | NFE Backward 50(50.1) | CNF Time 0.5000(0.5000)
# Iter 1428 | Time 0.4240(0.4235) | Loss -0.632628(-0.751148) | NFE Forward 50(49.5) | NFE Backward 50(50.1) | CNF Time 0.5000(0.5000)
# Iter 1429 | Time 0.4551(0.4257) | Loss -0.147249(-0.708875) | NFE Forward 50(49.6) | NFE Backward 56(50.5) | CNF Time 0.5000(0.5000)
# Iter 1430 | Time 0.4229(0.4255) | Loss -0.370073(-0.685159) | NFE Forward 50(49.6) | NFE Backward 50(50.4) | CNF Time 0.5000(0.5000)
# Iter 1431 | Time 0.4215(0.4253) | Loss -0.939960(-0.702995) | NFE Forward 50(49.6) | NFE Backward 50(50.4) | CNF Time 0.5000(0.5000)
# Iter 1432 | Time 0.3939(0.4231) | Loss -1.078686(-0.729293) | NFE Forward 50(49.7) | NFE Backward 44(50.0) | CNF Time 0.5000(0.5000)
# Iter 1433 | Time 0.4265(0.4233) | Loss -1.221396(-0.763740) | NFE Forward 50(49.7) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 1434 | Time 0.4251(0.4234) | Loss -1.253680(-0.798036) | NFE Forward 50(49.7) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 1435 | Time 0.4265(0.4236) | Loss -0.263111(-0.760591) | NFE Forward 50(49.7) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 1436 | Time 0.4271(0.4239) | Loss -0.079005(-0.712880) | NFE Forward 50(49.7) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 1437 | Time 0.4260(0.4240) | Loss -1.120102(-0.741386) | NFE Forward 50(49.8) | NFE Backward 50(50.0) | CNF Time 0.5000(0.5000)
# Iter 1438 | Time 0.4552(0.4262) | Loss -0.686919(-0.737573) | NFE Forward 50(49.8) | NFE Backward 56(50.4) | CNF Time 0.5000(0.5000)
# Iter 1439 | Time 0.4193(0.4257) | Loss -0.608454(-0.728535) | NFE Forward 50(49.8) | NFE Backward 50(50.4) | CNF Time 0.5000(0.5000)
# Iter 1440 | Time 0.4184(0.4252) | Loss -1.250156(-0.765048) | NFE Forward 50(49.8) | NFE Backward 50(50.3) | CNF Time 0.5000(0.5000)
# Iter 1441 | Time 0.4486(0.4269) | Loss -0.393222(-0.739021) | NFE Forward 50(49.8) | NFE Backward 56(50.7) | CNF Time 0.5000(0.5000)
# Iter 1442 | Time 0.4206(0.4264) | Loss -0.481998(-0.721029) | NFE Forward 50(49.8) | NFE Backward 50(50.7) | CNF Time 0.5000(0.5000)
# Iter 1443 | Time 0.3840(0.4234) | Loss -0.740353(-0.722382) | NFE Forward 50(49.8) | NFE Backward 44(50.2) | CNF Time 0.5000(0.5000)
# Iter 1444 | Time 0.4199(0.4232) | Loss -1.007233(-0.742321) | NFE Forward 50(49.9) | NFE Backward 50(50.2) | CNF Time 0.5000(0.5000)
# Iter 1445 | Time 0.4218(0.4231) | Loss -1.156009(-0.771279) | NFE Forward 44(49.4) | NFE Backward 50(50.2) | CNF Time 0.5000(0.5000)
# Iter 1446 | Time 0.4218(0.4230) | Loss -0.862718(-0.777680) | NFE Forward 50(49.5) | NFE Backward 50(50.2) | CNF Time 0.5000(0.5000)
# Iter 1447 | Time 0.3968(0.4212) | Loss -0.841221(-0.782128) | NFE Forward 50(49.5) | NFE Backward 44(49.7) | CNF Time 0.5000(0.5000)
# Iter 1448 | Time 0.3864(0.4187) | Loss -1.367977(-0.823137) | NFE Forward 44(49.1) | NFE Backward 44(49.3) | CNF Time 0.5000(0.5000)
# Iter 1449 | Time 0.4239(0.4191) | Loss -1.346830(-0.859796) | NFE Forward 50(49.2) | NFE Backward 50(49.4) | CNF Time 0.5000(0.5000)
# Iter 1450 | Time 0.3950(0.4174) | Loss -0.709540(-0.849278) | NFE Forward 50(49.3) | NFE Backward 44(49.0) | CNF Time 0.5000(0.5000)
