# %%
import os

# %%
files = os.listdir('D:\\forClone\\Hiwi\\results_mtemp_hilo_ply\\.')

# %%
# Out:
# ['change_ply23d.py', 'gg_3dvisual_temperature.pdf', 'go_3dvisual_temperature.pdf', 'sample_1gg1.3d', 'sample_1gg2.3d', 'sample_1gg3.3d', 'sample_1gg4.3d', 'sample_1gg5.3d', 'sample_1gg6.3d', 'sample_1info1.3d', 'sample_1info2.3d', 'sample_1info3.3d', 'sample_1info4.3d', 'sample_1info5.3d', 'sample_1info6.3d', 'sample_1_go1.3d', 'sample_1_go2.3d', 'sample_1_go3.3d', 'sample_1_go4.3d', 'sample_1_go5.3d', 'sample_1_go6.3d', 'sample_2gg1.3d', 'sample_2gg2.3d', 'sample_2gg3.3d', 'sample_2gg4.3d', 'sample_2gg5.3d', 'sample_2gg6.3d', 'sample_2info1.3d', 'sample_2info2.3d', 'sample_2info3.3d', 'sample_2info4.3d', 'sample_2info5.3d', 'sample_2info6.3d', 'sample_2_go1.3d', 'sample_2_go2.3d', 'sample_2_go3.3d', 'sample_2_go4.3d', 'sample_2_go5.3d', 'sample_2_go6.3d', 'sample_3gg1.3d', 'sample_3gg2.3d', 'sample_3gg3.3d', 'sample_3gg4.3d', 'sample_3gg5.3d', 'sample_3gg6.3d', 'sample_3info1.3d', 'sample_3info2.3d', 'sample_3info3.3d', 'sample_3info4.3d', 'sample_3info5.3d', 'sample_3info6.3d', 'sa
# ...

# %%
for filename in files:
    print(filename)
    portion = os.path.splitext(filename)
    print(portion)
    if portion[1] == ".3d":
        newname = portion[0]+'.ply'
        os.rename("D:\\forClone\\Hiwi\\results_mtemp_hilo_ply\\"+filename, newname)
# Out:
# change_ply23d.py
# ('change_ply23d', '.py')
# gg_3dvisual_temperature.pdf
# ('gg_3dvisual_temperature', '.pdf')
# go_3dvisual_temperature.pdf
# ('go_3dvisual_temperature', '.pdf')
# sample_1gg1.3d
# ('sample_1gg1', '.3d')
# sample_1gg2.3d
# ('sample_1gg2', '.3d')
# sample_1gg3.3d
# ('sample_1gg3', '.3d')
# sample_1gg4.3d
# ('sample_1gg4', '.3d')
# sample_1gg5.3d
# ('sample_1gg5', '.3d')
# sample_1gg6.3d
# ('sample_1gg6', '.3d')
# sample_1info1.3d
# ('sample_1info1', '.3d')
# sample_1info2.3d
# ('sample_1info2', '.3d')
# sample_1info3.3d
# ('sample_1info3', '.3d')
# sample_1info4.3d
# ('sample_1info4', '.3d')
# sample_1info5.3d
# ('sample_1info5', '.3d')
# sample_1info6.3d
# ('sample_1info6', '.3d')
# sample_1_go1.3d
# ('sample_1_go1', '.3d')
# sample_1_go2.3d
# ('sample_1_go2', '.3d')
# sample_1_go3.3d
# ('sample_1_go3', '.3d')
# sample_1_go4.3d
# ('sample_1_go4', '.3d')
# sample_1_go5.3d
# ('sample_1_go5', '.3d')
# sample_1_go6.3d
# ('sample_1_go6', '.3d')
# sample_2gg1.3d
# ...
